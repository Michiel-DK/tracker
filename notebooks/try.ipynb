# %% [markdown]
# ## TRACKER PACKAGE TEST

# %%
from tracker.data import Data

# %%
adbe = Data('ADBE', 'quarter', '12')

# %%
adbe.get_financials()
# Out:
#         EBITDA  accountsPayable capitalSurplus  cashChange    cashFlow  \
# 0   1526501200        334420017           None  6401551571  6759014665
# 1   1467629092        317732322           None  5974857229           0
# 2   1557714157        255760792           None  5126967258  1860566777
# 3   1294440317        307033597           None  6055195964  1842530815
# 4   1141270509        236539725           None  5334975625  4124915115
# 5   1076251095        300513148           None  4424952458     1201541
# 6   1008594833        269835531           None  4206290748     1345974
# 7   1044661578        219545866           None  4310187801           0
# 8    926163805        195371313           None  3820688783 -2245526546
# 9    813305928        170691697           None  3517113559           0
# 10   777233004        150439400           None  3349837850           0
# 11   760253858        186272765           None  3374610365  4172926156
#
#     cashFlowFinancing  changesInInventories  changesInReceivables  \
# 0         -4188642622                     0            1599458147
# 1                   0                     0            1511247537
# 2         -1267528761                     0            1576843025
# 3          -960466904                     0            1446002967
# 4         -2637434874                     0            1356243107
# 5             -936114                     0            1429196340
# 6            -1267179                     0            1405959483
# 7                   0                     0            1572471833
# 8          1528724391                     0            1394330419
# 9                   0                     0            1299200098
# 10                  0                     0            1400141143
# 11           -5779973                     0            1338443195
#
#     commonStock  costOfRevenue  ...   totalDebt  totalInvestingCashFlows  \
# 0     494995085      471478083  ...  4255734491              -1934643388
# 1     483334870      446792793  ...  4249553920                        0
# 2     493294125      465763543  ...  4312219918              -1595957029
# 3     495621863      444029367  ...  4150603073               -133285841
# 4     494690004      432375835  ...  4243222300               -297179289
# 5     492610801      429323972  ...  4161110769                    82094
# 6     499966932      453493145  ...  4130935953                   -50391
# 7     488041460      461937802  ...  4243608123                        0
# 8     507131149      425950334  ...  4255293423                233371364
# 9     498977321      414102043  ...  4205690314                        0
# 10    495697737      408463415  ...  4229292981                        0
# 11    497904558      374775211  ...  4153924286              -4705939832
#
#     totalLiabilities  totalRevenue  treasuryStock          id   key  \
# 0        11835412204    4123640534   -16662178362  IICANFSLAN  BEDA
# 1        11967628879    3917387377   -16171107878  IFLINNSACA  EBDA
# 2        11726407502    4049657317   -15142363718  ANLFCIANSI  BAED
# 3        11028139762    3456620204   -13658553490  FANCLAISIN  DBAE
# 4        10784031679    3334738904   -13210408035  NIASNAICLF  DABE
# 5        10902901202    3269995710   -12609229060  FLNINAIASC  BAED
# 6        10869911067    3116322087   -11518722840  NIFLANICAS  BEDA
# 7        10658046465    3050457421   -11110605064  AILAFSNCNI  BEDA
# 8        10138819245    2858136095   -10238801855  FLNIINACSA  ABDE
# 9        10046897099    2838550384    -9361538212  NISCLIAANF  ABED
# 10        9983629408    2633420885    -8618755281  CNFIIANSLA  DBEA
# 11        9539479098    2533454490    -8086132199  SIFANICANL  DBEA
#
#        subkey           date        updated
# 0   quarterly  1630627200000  1702997261066
# 1   quarterly  1622764800000  1670916561820
# 2   quarterly  1614902400000  1691093949394
# 3   quarterly  1606435200000  1645619303387
# 4   quarterly  1598572800000  1669077237001
# 5   quarterly  1590710400000  1650003484348
# 6   quarterly  1582848000000  1645037790933
# 7   quarterly  1574985600000  1643950710885
# 8   quarterly  1567123200000  1649072048779
# 9   quarterly  1559260800000  1705693486945
# 10  quarterly  1551398400000  1639109932241
# 11  quarterly  1543536000000  1689277822659
#
# [12 rows x 70 columns]

# %%
adbe.preprocess()
# Out:
#         ebitda  accountspayable capitalsurplus  cashchange    cashflow  \
# 0   1531505917        340068581           None  6193503390  6815909988
# 1   1490952133        320926958           None  5880468892           0
# 2   1522786584        261430869           None  5100115813  1834585244
# 3   1272432007        319043904           None  6085868283  1797953858
# 4   1151228406        234958210           None  5355298064  3983529411
# 5   1056165799        299404251           None  4554096275     1203550
# 6   1017204659        267156215           None  4218480092     1330953
# 7   1055997539        210013553           None  4301192551           0
# 8    898287100        189302810           None  3743845114 -2269398163
# 9    823903693        175478898           None  3569861269           0
# 10   754117829        152154289           None  3359239218           0
# 11   769819362        193795347           None  3330816281  4201273540
#
#     cashflowfinancing  changesininventories  changesinreceivables  \
# 0         -4307291041                     0            1565325138
# 1                   0                     0            1537423891
# 2         -1259175574                     0            1526131824
# 3          -956160683                     0            1406318492
# 4         -2592776467                     0            1363132571
# 5             -935198                     0            1379299893
# 6            -1256985                     0            1418751647
# 7                   0                     0            1560740807
# 8          1486237939                     0            1406101757
# 9                   0                     0            1292038378
# 10                  0                     0            1362664807
# 11           -5747477                     0            1328028070
#
#     commonstock  costofrevenue  ... totalinvestingcashflows  totalliabilities  \
# 0     497858709      480387298  ...             -1975901186       11927908380
# 1     482633618      446292675  ...                       0       11826989352
# 2     486815502      460154805  ...             -1571317833       11684027321
# 3     499520719      428757804  ...              -137105012       11206563528
# 4     493331040      439358432  ...              -295367564       11039865581
# 5     504772982      422777934  ...                   83767       10856531724
# 6     484649146      473450955  ...                  -48787       10777701398
# 7     507771760      456170470  ...                       0       10560753833
# 8     486780414      422699024  ...               231939761       10045883150
# 9     504668823      426910843  ...                       0       10074745135
# 10    509707634      403785332  ...                       0        9674807456
# 11    494602596      360553322  ...             -4746806414        9806298169
#
#     totalrevenue  treasurystock          id   key     subkey           date  \
# 0     4099278188   -17075964986  ILSNCAFNAI  ABDE  quarterly  1630627200000
# 1     4017425888   -15677541413  NCFNAIASIL  ABDE  quarterly  1622764800000
# 2     4084152764   -15026741057  AFINSILANC  ABDE  quarterly  1614902400000
# 3     3539255089   -14031641893  SANCNLAFII  DBEA  quarterly  1606435200000
# 4     3354683558   -13055958098  FILSNANCIA  AEDB  quarterly  1598572800000
# 5     3217110163   -12584147312  IFANCNSLAI  EABD  quarterly  1590710400000
# 6     3130829246   -11434649897  CAASNIIFLN  EABD  quarterly  1582848000000
# 7     3139081597   -11059176614  CFNSIAINLA  DABE  quarterly  1574985600000
# 8     2968196591   -10331391029  AINNAFLISC  DBEA  quarterly  1567123200000
# 9     2834470869    -9196584748  CANINILAFS  DEBA  quarterly  1559260800000
# 10    2641765279    -8690433239  FIILNNCSAA  ABED  quarterly  1551398400000
# 11    2464632663    -8056189580  SLACANFIIN  BDAE  quarterly  1543536000000
#
#           updated ticker
# 0   1680941527489   ADBE
# 1   1637545232749   ADBE
# 2   1643224896896   ADBE
# 3   1642871022601   ADBE
# 4   1675441004966   ADBE
# 5   1690725654350   ADBE
# 6   1632828266444   ADBE
# 7   1695643416583   ADBE
# 8   1680263003690   ADBE
# 9   1689060553114   ADBE
# 10  1686581852454   ADBE
# 11  1639445551411   ADBE
#
# [12 rows x 71 columns]

# %%
full_table = adbe.add_fundamentals()

# %%
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
full_table.dtypes
# Out:
# ebitda                       int64
# accountspayable              int64
# capitalsurplus              object
# cashchange                   int64
# cashflow                     int64
# cashflowfinancing            int64
# changesininventories         int64
# changesinreceivables         int64
# commonstock                  int64
# costofrevenue                int64
# currency                    object
# currentassets                int64
# currentcash                  int64
# currentdebt                  int64
# currentlongtermdebt          int64
# depreciation                 int64
# dividendspaid               object
# ebit                         int64
# exchangerateeffect          object
# filingtype                  object
# fiscaldate                  object
# fiscalquarter                int64
# fiscalyear                   int64
# goodwill                     int64
# grossprofit                  int64
# incometax                    int64
# intangibleassets             int64
# interestincome               int64
# inventory                    int64
# investingactivityother      object
# investments                 object
# longtermdebt                 int64
# longterminvestments          int64
# minorityinterest             int64
# netborrowings                int64
# netincome                    int64
# netincomebasic               int64
# nettangibleassets            int64
# operatingexpense             int64
# operatingincome              int64
# operatingrevenue             int64
# otherassets                  int64
# othercurrentassets           int64
# othercurrentliabilities      int64
# otherincomeexpensenet        int64
# otherliabilities             int64
# pretaxincome                 int64
# propertyplantequipment       int64
# receivables                  int64
# reportdate                  object
# researchanddevelopment       int64
# retainedearnings             int64
# revenue                      int64
# sellinggeneralandadmin       int64
# shareholderequity            int64
# shorttermdebt                int64
# shortterminvestments         int64
# symbol                      object
# totalassets                  int64
# totalcash                    int64
# totaldebt                    int64
# totalinvestingcashflows      int64
# totalliabilities             int64
# totalrevenue                 int64
# treasurystock                int64
# id                          object
# key                         object
# subkey                      object
# date                         int64
# updated                      int64
# ticker                      object
# fcf                          int64
# operating_margin           float64
# net_margin                 float64
# asset_turnover             float64
# roa                        float64
# equity_multipl             float64
# roe                        float64
# fcf_margin                 float64
# cash_debt                  float64
# equity_asset               float64
# debt_equity                float64
# debt_ebitda                float64
# dtype: object

# %% [markdown]
# ## DB CONNECTION TEST

# %%
from tracker.postgres import connect

# %%
connect()
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 13.5 on x86_64-apple-darwin19.6.0, compiled by Apple clang version 11.0.3 (clang-1103.0.32.62), 64-bit',)
# Database connection closed.
