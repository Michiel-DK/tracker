# %% [markdown]
# ## TRACKER PACKAGE TEST

# %%
from tracker.data_iex import Data

# %%
adbe = Data('AAPL', 'quarter', '12')

# %%
adbe.get_financials()
# Out:
# Mem. usage decreased to 0.01 Mb (8.4% reduction)
#          EBITDA  accountsPayable capitalSurplus    cashChange     cashFlow  \
# 0   55749087542     112015317762           None  125466600537  41557250621
# 1   56328732904      81867757559           None  127889016838  44129550419
# 2   61242553306      80624356162           None  146061369442  49226111752
# 3   73721580230     132906312695           None  160651919678  79248646154
# 4   18334618857      43886642069           None   94023206632  21242718177
# 5   16455112258      36448908738           None   97669944318  16441084644
# 6   16338144144      32751998444           None   98462517632  13463976386
# 7   28570629355      45814356714           None  107371485627  31163987133
# 8   29297420674      47068186272           None  101131049520  70857361881
# 9   11853082646      29618427745           None   97044504252            0
# 10  13703646714      30453550869           None   80265412388            0
# 11  23741448662      46103546224           None   90549001457            0
#
#     cashFlowFinancing  changesInInventories  changesInReceivables  \
# 0        -41893922639           13523738954          103584866389
# 1        -61416088529           10395701364           68535086817
# 2        -22864130847           10881299732           68084668286
# 3        -65531154080           10090440087          117640243301
# 4        -22255113220            4247227471           37764422045
# 5        -19216211787            4138637024           33405670557
# 6        -21718705658            3365345530           31512493076
# 7        -26438862355            4259451771           41240857700
# 8        -91455183311            4297854402           47021505942
# 9                   0            3433917546           27659587214
# 10                  0            5117675534           26629169911
# 11                  0            5199727988           37646267955
#
#     commonStock  costOfRevenue  ...     totalDebt  totalInvestingCashFlows  \
# 0   34059342926    96429682707  ...  252849666081               1723634079
# 1   33826888727    95939286678  ...  247324941702             -71353908180
# 2   34929960292   106717459415  ...  254995813869              57465617359
# 3   35067633498   135558911021  ...  233000235398             -17296893903
# 4   17577507579    40282903849  ...  116057406993               5582336433
# 5   17604213610    37803188985  ...  117149508429              -5178467985
# 6   17673506650    36246421662  ...  112396418681               9331475934
# 7   17912094740    59013852540  ...  111007153490             -13997490025
# 8   18023018845    40537144964  ...  109700322283              48095478336
# 9   18492016657    33990561371  ...  112159154670                        0
# 10  18798056321    37393626338  ...  116129582864                        0
# 11  19515572429    54105478746  ...  119955425463                        0
#
#     totalLiabilities  totalRevenue  treasuryStock          id   key  \
# 0       577209470688  172944724226              0  FINNACSALI  LAAP
# 1       556434272326  165856921209              0  NFNSLAAIIC  AAPL
# 2       558242142255  179441227472              0  FLNAASNCII  AALP
# 3       588766510425  223963057004              0  NFNAAICSLI  AALP
# 4       263233956121   66876852223              0  AINNLAIFSC  PAAL
# 5       245247800061   61938869975              0  FSAICNANLI  PALA
# 6       242399233570   60889887832              0  NLASAINCFI  ALPA
# 7       257842426120   95190566582              0  SCIIAAFNLN  LAAP
# 8       257338741375   65084786877              0  IIASAFNLNC  LPAA
# 9       230913971785   55483749449              0  INFALICSNA  AALP
# 10      239311604428   58608592980              0  ICANNILFSA  LAPA
# 11      260539578601   87899646246              0  AANSFCILIN  PLAA
#
#        subkey           date        updated
# 0   quarterly  1632528000000  1636054026400
# 1   quarterly  1624665600000  1705414984355
# 2   quarterly  1616803200000  1691039534474
    if (df.loc[i]=='int64')[0]:
        print(f"{i} BIGINT,")
    elif (df.loc[i]=='object')[0]:
        print(f"{i} VARCHAR(n),")
    else:
        print(f"{i} REAL,")
# Out:
# ebitda BIGINT,
# accountspayable BIGINT,
# capitalsurplus VARCHAR(n),
# cashchange BIGINT,
# cashflow BIGINT,
# cashflowfinancing BIGINT,
# changesininventories BIGINT,
# changesinreceivables BIGINT,
# commonstock BIGINT,
# costofrevenue BIGINT,
# currency VARCHAR(n),
# currentassets BIGINT,
# currentcash BIGINT,
# currentdebt BIGINT,
# currentlongtermdebt BIGINT,
# depreciation BIGINT,
# dividendspaid VARCHAR(n),
# ebit BIGINT,
# exchangerateeffect VARCHAR(n),
# filingtype VARCHAR(n),
# fiscaldate VARCHAR(n),
# fiscalquarter BIGINT,
# fiscalyear BIGINT,
# goodwill BIGINT,
# grossprofit BIGINT,
# incometax BIGINT,
# intangibleassets BIGINT,
# interestincome BIGINT,
# inventory BIGINT,
# investingactivityother VARCHAR(n),
# investments VARCHAR(n),
# longtermdebt BIGINT,
# longterminvestments BIGINT,
# minorityinterest BIGINT,
# netborrowings BIGINT,
# netincome BIGINT,
# netincomebasic BIGINT,
# nettangibleassets BIGINT,
# operatingexpense BIGINT,
# operatingincome BIGINT,
# operatingrevenue BIGINT,
# otherassets BIGINT,
# othercurrentassets BIGINT,
# othercurrentliabilities BIGINT,
# otherincomeexpensenet BIGINT,
# otherliabilities BIGINT,
# pretaxincome BIGINT,
# propertyplantequipment BIGINT,
# receivables BIGINT,
# reportdate VARCHAR(n),
# researchanddevelopment BIGINT,
# retainedearnings BIGINT,
# revenue BIGINT,
# sellinggeneralandadmin BIGINT,
# shareholderequity BIGINT,
# shorttermdebt BIGINT,
# shortterminvestments BIGINT,
# symbol VARCHAR(n),
# totalassets BIGINT,
# totalcash BIGINT,
# totaldebt BIGINT,
# totalinvestingcashflows BIGINT,
# totalliabilities BIGINT,
# totalrevenue BIGINT,
# treasurystock BIGINT,
# id VARCHAR(n),
# key VARCHAR(n),
# subkey VARCHAR(n),
# date BIGINT,
# updated BIGINT,
# ticker VARCHAR(n),
# fcf BIGINT,
# operating_margin REAL,
# net_margin REAL,
# asset_turnover REAL,
# roa REAL,
# equity_multipl REAL,
# roe REAL,
# fcf_margin REAL,
# cash_debt REAL,
# equity_asset REAL,
# debt_equity REAL,
# debt_ebitda REAL,

# %%
from tracker.data_yahoo import Yahoo

# %%
import yfinance as yf
info = yf.Ticker('MSFT').earnings

# %%
earnings = yf.Ticker('MSFT').quarterly_earnings
earnings
# Out:
#              Revenue     Earnings
# Quarter
# 1Q2021   41706000000  15457000000
# 2Q2021   46152000000  16458000000
# 3Q2021   45317000000  20505000000
# 4Q2021   51728000000  18765000000

# %%
earnings_T = earnings.sort_values(by='Quarter', ascending=False).T
earnings_T
# Out:
# Quarter        4Q2021       3Q2021       2Q2021       1Q2021
# Revenue   51728000000  45317000000  46152000000  41706000000
# Earnings  18765000000  20505000000  16458000000  15457000000

# %%
earnings_T.columns = [f"{i[-4:]}{i[1]}{i[0]}" for i in list(earnings_T.columns)]
earnings_T
# Out:
#                2021Q4       2021Q3       2021Q2       2021Q1
# Revenue   51728000000  45317000000  46152000000  41706000000
# Earnings  18765000000  20505000000  16458000000  15457000000

# %%
earnings_T = earnings.T

# %%
[f"{i[-4:]}{i[1]}{i[0]}" for i in list(earnings_T.columns)]
# Out:
# ['2021Q1', '2021Q2', '2021Q3', '2021Q4']

# %%
earnings.columns.apply(lambda x: f"{i[-4:]}{i[1]}{i[0]}" for i in x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [105], in <module>
# ----> 1 earnings.columns.apply(lambda x: f"{i[-4:]}{i[1]}{i[0]}" for i in x)
#
# AttributeError: 'Index' object has no attribute 'apply'

# %%
earnings.columns.map(lambda x: change_index(x))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [107], in <module>
# ----> 1 earnings.columns.map(lambda x: change_index(x))
#
# File ~/.pyenv/versions/3.8.12/envs/tracker/lib/python3.8/site-packages/pandas/core/indexes/base.py:5506, in Index.map(self, mapper, na_action)
#    5486 """
#    5487 Map values using input correspondence (a dict, Series, or function).
#    5488
#    (...)
#    5502     a MultiIndex will be returned.
#    5503 """
#    5504 from pandas.core.indexes.multi import MultiIndex
# -> 5506 new_values = self._map_values(mapper, na_action=na_action)
#    5508 attributes = self._get_attributes_dict()
#    5510 # we can return a MultiIndex
#
# File ~/.pyenv/versions/3.8.12/envs/tracker/lib/python3.8/site-packages/pandas/core/base.py:870, in IndexOpsMixin._map_values(self, mapper, na_action)
#     867         raise ValueError(msg)
#     869 # mapper is a function
# --> 870 new_values = map_f(values, mapper)
#     872 return new_values
#
# File ~/.pyenv/versions/3.8.12/envs/tracker/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2859, in pandas._libs.lib.map_infer()
#
# Input In [107], in <lambda>(x)
# ----> 1 earnings.columns.map(lambda x: change_index(x))
#
# Input In [99], in change_index(index)
#       2 def change_index(index):
#       3     for i in index:
#       4         #print(i)
#       5         #ls.append(f"{i[-4:]}{i[1]}{i[0]}")
# ----> 6         return f"{i[-4:]}{i[1]}{i[0]}"
#
# IndexError: string index out of range

# %%
ls = []
def change_index(index):
    for i in index:
        #print(i)
        #ls.append(f"{i[-4:]}{i[1]}{i[0]}")
        return f"{i[-4:]}{i[1]}{i[0]}"

# %%
earnings.index.map(change_index)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [100], in <module>
# ----> 1 earnings.index.map(change_index)
#
# File ~/.pyenv/versions/3.8.12/envs/tracker/lib/python3.8/site-packages/pandas/core/indexes/base.py:5506, in Index.map(self, mapper, na_action)
#    5486 """
#    5487 Map values using input correspondence (a dict, Series, or function).
#    5488
#    (...)
#    5502     a MultiIndex will be returned.
#    5503 """
#    5504 from pandas.core.indexes.multi import MultiIndex
# -> 5506 new_values = self._map_values(mapper, na_action=na_action)
#    5508 attributes = self._get_attributes_dict()
#    5510 # we can return a MultiIndex
#
# File ~/.pyenv/versions/3.8.12/envs/tracker/lib/python3.8/site-packages/pandas/core/base.py:870, in IndexOpsMixin._map_values(self, mapper, na_action)
#     867         raise ValueError(msg)
#     869 # mapper is a function
# --> 870 new_values = map_f(values, mapper)
#     872 return new_values
#
# File ~/.pyenv/versions/3.8.12/envs/tracker/lib/python3.8/site-packages/pandas/_libs/lib.pyx:2859, in pandas._libs.lib.map_infer()
#
# Input In [99], in change_index(index)
#       2 def change_index(index):
#       3     for i in index:
#       4         #print(i)
#       5         #ls.append(f"{i[-4:]}{i[1]}{i[0]}")
# ----> 6         return f"{i[-4:]}{i[1]}{i[0]}"
#
# IndexError: string index out of range

# %%
change_index(earnings.index)

# %%
earnings.index = ls

# %%
earnings
# Out:
#             Revenue     Earnings
# 2021Q1  41706000000  15457000000
# 2021Q2  46152000000  16458000000
# 2021Q3  45317000000  20505000000
# 2021Q4  51728000000  18765000000

# %%
earnings.index = earnings.index.map(lambda x: f"{i[-4:]}{i[1]}{i[0]}" for i in x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [80], in <module>
# ----> 1 earnings.index = earnings.index.map(lambda x: f"{i[-4:]}{i[1]}{i[0]}" for i in x)
#
# NameError: name 'x' is not defined

# %%
earnings
# Out:
#              Revenue     Earnings
# Quarter
# 2021Q4   41706000000  15457000000
# 2021Q4   46152000000  16458000000
# 2021Q4   45317000000  20505000000
# 2021Q4   51728000000  18765000000

# %%
balance = yf.Ticker('MSFT').quarterly_balance_sheet
balance
# Out:
#                                     2021-12-31    2021-09-30    2021-06-30  \
# Intangible Assets                 7.462000e+09  7.794000e+09  7.800000e+09
# Total Liab                        1.803790e+11  1.834400e+11  1.917910e+11
# Total Stockholder Equity          1.600100e+11  1.519780e+11  1.419880e+11
# Other Current Liab                4.634600e+10  5.262200e+10  5.261200e+10
# Total Assets                      3.403890e+11  3.354180e+11  3.337790e+11
# Common Stock                      8.452800e+10  8.375100e+10  8.311100e+10
# Other Current Assets              1.230100e+10  1.298200e+10  1.347100e+10
# Retained Earnings                 7.504500e+10  6.694400e+10  5.705500e+10
# Other Liab                        3.058400e+10  3.015700e+10  3.168100e+10
# Good Will                         5.092100e+10  5.045500e+10  4.971100e+10
# Treasury Stock                    4.370000e+08  1.283000e+09  1.822000e+09
# Other Assets                      2.125600e+10  2.110300e+10  1.507500e+10
# Cash                              2.060400e+10  1.916500e+10  1.422400e+10
# Total Current Liabilities         7.751000e+10  8.052800e+10  8.865700e+10
# Short Long Term Debt              4.998000e+09  3.249000e+09  8.072000e+09
# Other Stockholder Equity          4.370000e+08  1.283000e+09  1.822000e+09
# Property Plant Equipment          7.956800e+10  7.534700e+10  7.080300e+10
# Total Current Assets              1.741880e+11  1.743260e+11  1.844060e+11
# Long Term Investments             6.994000e+09  6.393000e+09  5.984000e+09
# Net Tangible Assets               1.016270e+11  9.372900e+10  8.447700e+10
# Short Term Investments            1.047440e+11  1.114190e+11  1.160320e+11
# Net Receivables                   3.352000e+10  2.734900e+10  3.804300e+10
# Long Term Debt                    4.826000e+10  5.003900e+10  5.007400e+10
# Inventory                         3.019000e+09  3.411000e+09  2.636000e+09
# Accounts Payable                  1.531400e+10  1.483200e+10  1.516300e+10
# Deferred Long Term Asset Charges           NaN           NaN  7.181000e+09
#
#                                     2021-03-31
# Intangible Assets                 8.127000e+09
# Total Liab                        1.743740e+11
# Total Stockholder Equity          1.345050e+11
# Other Current Liab                4.006900e+10
# Total Assets                      3.088790e+11
# Common Stock                      8.230800e+10
# Other Current Assets              1.203400e+10
# Retained Earnings                 5.073500e+10
# Other Liab                        3.160100e+10
# Good Will                         4.969800e+10
# Treasury Stock                    1.462000e+09
# Other Assets                      1.442700e+10
# Cash                              1.370200e+10
# Total Current Liabilities         7.219300e+10
# Short Long Term Debt              8.051000e+09
# Other Stockholder Equity          1.462000e+09
# Property Plant Equipment          6.561800e+10
# Total Current Assets              1.656140e+11
# Long Term Investments             5.395000e+09
# Net Tangible Assets               7.668000e+10
# Short Term Investments            1.113110e+11
# Net Receivables                   2.632200e+10
# Long Term Debt                    5.000700e+10
# Inventory                         2.245000e+09
# Accounts Payable                  1.341200e+10
# Deferred Long Term Asset Charges           NaN

# %%
balance.columns = [f"{i.year}Q{i.quarter}" for i in list(balance.columns)]
balance
# Out:
#                                         2021Q4        2021Q3        2021Q2  \
# Intangible Assets                 7.462000e+09  7.794000e+09  7.800000e+09
# Total Liab                        1.803790e+11  1.834400e+11  1.917910e+11
# Total Stockholder Equity          1.600100e+11  1.519780e+11  1.419880e+11
# Other Current Liab                4.634600e+10  5.262200e+10  5.261200e+10
# Total Assets                      3.403890e+11  3.354180e+11  3.337790e+11
# Common Stock                      8.452800e+10  8.375100e+10  8.311100e+10
# Other Current Assets              1.230100e+10  1.298200e+10  1.347100e+10
# Retained Earnings                 7.504500e+10  6.694400e+10  5.705500e+10
# Other Liab                        3.058400e+10  3.015700e+10  3.168100e+10
# Good Will                         5.092100e+10  5.045500e+10  4.971100e+10
# Treasury Stock                    4.370000e+08  1.283000e+09  1.822000e+09
# Other Assets                      2.125600e+10  2.110300e+10  1.507500e+10
# Cash                              2.060400e+10  1.916500e+10  1.422400e+10
# Total Current Liabilities         7.751000e+10  8.052800e+10  8.865700e+10
# Short Long Term Debt              4.998000e+09  3.249000e+09  8.072000e+09
# Other Stockholder Equity          4.370000e+08  1.283000e+09  1.822000e+09
# Property Plant Equipment          7.956800e+10  7.534700e+10  7.080300e+10
# Total Current Assets              1.741880e+11  1.743260e+11  1.844060e+11
# Long Term Investments             6.994000e+09  6.393000e+09  5.984000e+09
# Net Tangible Assets               1.016270e+11  9.372900e+10  8.447700e+10
# Short Term Investments            1.047440e+11  1.114190e+11  1.160320e+11
# Net Receivables                   3.352000e+10  2.734900e+10  3.804300e+10
# Long Term Debt                    4.826000e+10  5.003900e+10  5.007400e+10
# Inventory                         3.019000e+09  3.411000e+09  2.636000e+09
# Accounts Payable                  1.531400e+10  1.483200e+10  1.516300e+10
# Deferred Long Term Asset Charges           NaN           NaN  7.181000e+09
#
#                                         2021Q1
# Intangible Assets                 8.127000e+09
# Total Liab                        1.743740e+11
# Total Stockholder Equity          1.345050e+11
# Other Current Liab                4.006900e+10
# Total Assets                      3.088790e+11
# Common Stock                      8.230800e+10
# Other Current Assets              1.203400e+10
# Retained Earnings                 5.073500e+10
# Other Liab                        3.160100e+10
# Good Will                         4.969800e+10
# Treasury Stock                    1.462000e+09
# Other Assets                      1.442700e+10
# Cash                              1.370200e+10
# Total Current Liabilities         7.219300e+10
# Short Long Term Debt              8.051000e+09
# Other Stockholder Equity          1.462000e+09
# Property Plant Equipment          6.561800e+10
# Total Current Assets              1.656140e+11
# Long Term Investments             5.395000e+09
# Net Tangible Assets               7.668000e+10
# Short Term Investments            1.113110e+11
# Net Receivables                   2.632200e+10
# Long Term Debt                    5.000700e+10
# Inventory                         2.245000e+09
# Accounts Payable                  1.341200e+10
# Deferred Long Term Asset Charges           NaN

# %%
cash = yf.Ticker('MSFT').quarterly_cashflow

# %%
for i in cash.columns:
    print(f"{i.year}Q{i.quarter}")
# Out:
# 2021Q4
# 2021Q3
# 2021Q2
# 2021Q1

# %%
cash.columns[0].quarter
# Out:
# 4

# %%
infoyf.Ticker('MSFT').quarterly_balance_sheet
# Out:
#            Revenue     Earnings
# Year
# 2018  110360000000  16571000000
# 2019  125843000000  39240000000
# 2020  143015000000  44281000000
# 2021  168088000000  61271000000

# %%
for i in info.keys():
    print(i)
# Out:
# zip
# sector
# fullTimeEmployees
# longBusinessSummary
# city
# phone
# state
# country
# companyOfficers
# website
# maxAge
# address1
# industry
# ebitdaMargins
# profitMargins
# grossMargins
# operatingCashflow
# revenueGrowth
# operatingMargins
# ebitda
# targetLowPrice
# recommendationKey
# grossProfits
# freeCashflow
# targetMedianPrice
# currentPrice
# earningsGrowth
# currentRatio
# returnOnAssets
# numberOfAnalystOpinions
# targetMeanPrice
# debtToEquity
# returnOnEquity
# targetHighPrice
# totalCash
# totalDebt
# totalRevenue
# totalCashPerShare
# financialCurrency
# revenuePerShare
# quickRatio
# recommendationMean
# exchange
# shortName
# longName
# exchangeTimezoneName
# exchangeTimezoneShortName
# isEsgPopulated
# gmtOffSetMilliseconds
# quoteType
# symbol
# messageBoardId
# market
# annualHoldingsTurnover
# enterpriseToRevenue
# beta3Year
# enterpriseToEbitda
# 52WeekChange
# morningStarRiskRating
# forwardEps
# revenueQuarterlyGrowth
# sharesOutstanding
# fundInceptionDate
# annualReportExpenseRatio
# totalAssets
# bookValue
# sharesShort
# sharesPercentSharesOut
# fundFamily
# lastFiscalYearEnd
# heldPercentInstitutions
# netIncomeToCommon
# trailingEps
# lastDividendValue
# SandP52WeekChange
# priceToBook
# heldPercentInsiders
# nextFiscalYearEnd
# yield
# mostRecentQuarter
# shortRatio
# sharesShortPreviousMonthDate
# floatShares
# beta
# enterpriseValue
# priceHint
# threeYearAverageReturn
# lastSplitDate
# lastSplitFactor
# legalType
# lastDividendDate
# morningStarOverallRating
# earningsQuarterlyGrowth
# priceToSalesTrailing12Months
# dateShortInterest
# pegRatio
# ytdReturn
# forwardPE
# lastCapGain
# shortPercentOfFloat
# sharesShortPriorMonth
# impliedSharesOutstanding
# category
# fiveYearAverageReturn
# previousClose
# regularMarketOpen
# twoHundredDayAverage
# trailingAnnualDividendYield
# payoutRatio
# volume24Hr
# regularMarketDayHigh
# navPrice
# averageDailyVolume10Day
# regularMarketPreviousClose
# fiftyDayAverage
# trailingAnnualDividendRate
# open
# toCurrency
# averageVolume10days
# expireDate
# algorithm
# dividendRate
# exDividendDate
# circulatingSupply
# startDate
# regularMarketDayLow
# currency
# trailingPE
# regularMarketVolume
# lastMarket
# maxSupply
# openInterest
# marketCap
# volumeAllCurrencies
# strikePrice
# averageVolume
# dayLow
# ask
# askSize
# volume
# fiftyTwoWeekHigh
# fromCurrency
# fiveYearAvgDividendYield
# fiftyTwoWeekLow
# bid
# tradeable
# dividendYield
# bidSize
# dayHigh
# regularMarketPrice
# preMarketPrice
# logo_url

# %%
#'HHFA.DE' 'PLTR'
tickers = ['ABBV','ADBE', 'AMGN', 'AY', 'BABA', 'CARM.PA', 'CRM', 'CRSP', 'CVS', 'DUKE.L', 'EURN', 'GAIN', 'GOOGL', 'HASI', 'NXR.L', 'MO', "MSFT", 'PYPL', 'RDS-A', 'SQ', 'TCPC', 'TDOC', "TSLX", 'TCPC', 'TTE', 'TRI.PA','V' , "WEHB.BR"]

# %%
names = []
for ticker in tickers:
    print(ticker)
    full = yf.Ticker(ticker).info
    for column in full.keys():
        names.append(column)
# Out:
# ABBV
# ADBE
# AMGN
# AY
# BABA
# CARM.PA
# CRM
# CRSP
# CVS
# DUKE.L
# EURN
# GAIN
# GOOGL
# HASI
# NXR.L
# MO
# MSFT
# PYPL
# RDS-A
# SQ
# TCPC
# TDOC
# TSLX
# TCPC
# TTE
# TRI.PA
# V
# WEHB.BR

# %%
names_origi = set(names)

# %%
        columns = ['52WeekChange',
                    'SandP52WeekChange',
                    'address1',
                    'address2',
                    'algorithm',
                    'annualHoldingsTurnover',
                    'annualReportExpenseRatio',
                    'ask',
                    'askSize',
                    'averageDailyVolume10Day',
                    'averageVolume',
                    'averageVolume10days',
                    'beta',
                    'beta3Year',
                    'bid',
                    'bidSize',
                    'bookValue',
                    'category',
                    'circulatingSupply',
                    'city',
                    'companyOfficers',
                    'country',
                    'currency',
                    'currentPrice',
                    'currentRatio',
                    'dateShortInterest',
                    'dayHigh',
                    'dayLow',
                    'debtToEquity',
                    'dividendRate',
                    'dividendYield',
                    'earningsGrowth',
                    'earningsQuarterlyGrowth',
                    'ebitda',
                    'ebitdaMargins',
                    'enterpriseToEbitda',
                    'enterpriseToRevenue',
                    'enterpriseValue',
                    'exDividendDate',
                    'exchange',
                    'exchangeTimezoneName',
                    'exchangeTimezoneShortName',
                    'expireDate',
                    'fax',
                    'fiftyDayAverage',
                    'fiftyTwoWeekHigh',
                    'fiftyTwoWeekLow',
                    'financialCurrency',
                    'fiveYearAverageReturn',
                    'fiveYearAvgDividendYield',
                    'floatShares',
                    'forwardEps',
                    'forwardPE',
                    'freeCashflow',
                    'fromCurrency',
                    'fullTimeEmployees',
                    'fundFamily',
                    'fundInceptionDate',
                    'gmtOffSetMilliseconds',
                    'grossMargins',
                    'grossProfits',
                    'heldPercentInsiders',
                    'heldPercentInstitutions',
                    'impliedSharesOutstanding',
                    'industry',
                    'isEsgPopulated',
                    'lastCapGain',
                    'lastDividendDate',
                    'lastDividendValue',
                    'lastFiscalYearEnd',
                    'lastMarket',
                    'lastSplitDate',
                    'lastSplitFactor',
                    'legalType',
                    'logo_url',
                    'longBusinessSummary',
                    'longName',
                    'market',
                    'marketCap',
                    'maxAge',
                    'maxSupply',
                    'messageBoardId',
                    'morningStarOverallRating',
                    'morningStarRiskRating',
                    'mostRecentQuarter',
                    'navPrice',
                    'netIncomeToCommon',
                    'nextFiscalYearEnd',
                    'numberOfAnalystOpinions',
                    'open',
                    'openInterest',
                    'operatingCashflow',
                    'operatingMargins',
                    'payoutRatio',
                    'pegRatio',
                    'phone',
                    'preMarketPrice',
                    'previousClose',
                    'priceHint',
                    'priceToBook',
                    'priceToSalesTrailing12Months',
                    'profitMargins',
                    'quickRatio',
                    'quoteType',
                    'recommendationKey',
                    'recommendationMean',
                    'regularMarketDayHigh',
                    'regularMarketDayLow',
                    'regularMarketOpen',
                    'regularMarketPreviousClose',
                    'regularMarketPrice',
                    'regularMarketVolume',
                    'returnOnAssets',
                    'returnOnEquity',
                    'revenueGrowth',
                    'revenuePerShare',
                    'revenueQuarterlyGrowth',
                    'sector',
                    'sharesOutstanding',
                    'sharesPercentSharesOut',
                    'sharesShort',
                    'sharesShortPreviousMonthDate',
                    'sharesShortPriorMonth',
                    'shortName',
                    'shortPercentOfFloat',
                    'shortRatio',
                    'startDate',
                    'state',
                    'strikePrice',
                    'symbol',
                    'targetHighPrice',
                    'targetLowPrice',
                    'targetMeanPrice',
                    'targetMedianPrice',
                    'threeYearAverageReturn',
                    'toCurrency',
                    'totalAssets',
                    'totalCash',
                    'totalCashPerShare',
                    'totalDebt',
                    'totalRevenue',
                    'tradeable',
                    'trailingAnnualDividendRate',
                    'trailingAnnualDividendYield',
                    'trailingEps',
                    'trailingPE',
                    'trailingPegRatio',
                    'twoHundredDayAverage',
                    'volume',
                    'volume24Hr',
                    'volumeAllCurrencies',
                    'website',
                    'yield',
                    'ytdReturn',
                    'zip']

# %%
len(columns)
# Out:
# 155

# %%
len(names_origi)
# Out:
# 155

# %%
import pandas as pd
import numpy as np
from datetime import date
pd.set_option("display.max_rows", None, "display.max_columns", None)

#empty = pd.DataFrame(columns=columns, index=[date.today().strftime("%d/%m/%Y")])

# %%
empty
# Out:
#            52WeekChange SandP52WeekChange address1 address2 algorithm  \
# 31/01/2022          NaN               NaN      NaN      NaN       NaN
#
#            annualHoldingsTurnover annualReportExpenseRatio  ask askSize  \
# 31/01/2022                    NaN                      NaN  NaN     NaN
#
#            averageDailyVolume10Day averageVolume averageVolume10days beta  \
# 31/01/2022                     NaN           NaN                 NaN  NaN
#
#            beta3Year  bid bidSize bookValue category circulatingSupply city  \
# 31/01/2022       NaN  NaN     NaN       NaN      NaN               NaN  NaN
#
#            companyOfficers country currency currentPrice currentRatio  \
# 31/01/2022             NaN     NaN      NaN          NaN          NaN
#
#            dateShortInterest dayHigh dayLow debtToEquity dividendRate  \
# 31/01/2022               NaN     NaN    NaN          NaN          NaN
#
#            dividendYield earningsGrowth earningsQuarterlyGrowth ebitda  \
# 31/01/2022           NaN            NaN                     NaN    NaN
#
#            ebitdaMargins enterpriseToEbitda enterpriseToRevenue  \
# 31/01/2022           NaN                NaN                 NaN
#
#            enterpriseValue exDividendDate exchange exchangeTimezoneName  \
# 31/01/2022             NaN            NaN      NaN                  NaN
#
#            exchangeTimezoneShortName expireDate  fax fiftyDayAverage  \
# 31/01/2022                       NaN        NaN  NaN             NaN
#
#            fiftyTwoWeekHigh fiftyTwoWeekLow financialCurrency  \
# 31/01/2022              NaN             NaN               NaN
#
#            fiveYearAverageReturn fiveYearAvgDividendYield floatShares  \
# 31/01/2022                   NaN                      NaN         NaN
#
#            forwardEps forwardPE freeCashflow fromCurrency fullTimeEmployees  \
# 31/01/2022        NaN       NaN          NaN          NaN               NaN
#
#            fundFamily fundInceptionDate gmtOffSetMilliseconds grossMargins  \
# 31/01/2022        NaN               NaN                   NaN          NaN
#
#            grossProfits heldPercentInsiders heldPercentInstitutions  \
# 31/01/2022          NaN                 NaN                     NaN
#
#            impliedSharesOutstanding industry isEsgPopulated lastCapGain  \
# 31/01/2022                      NaN      NaN            NaN         NaN
#
#            lastDividendDate lastDividendValue lastFiscalYearEnd lastMarket  \
# 31/01/2022              NaN               NaN               NaN        NaN
#
#            lastSplitDate lastSplitFactor legalType logo_url  \
# 31/01/2022           NaN             NaN       NaN      NaN
#
#            longBusinessSummary longName market marketCap maxAge maxSupply  \
# 31/01/2022                 NaN      NaN    NaN       NaN    NaN       NaN
#
#            messageBoardId morningStarOverallRating morningStarRiskRating  \
# 31/01/2022            NaN                      NaN                   NaN
#
#            mostRecentQuarter navPrice netIncomeToCommon nextFiscalYearEnd  \
# 31/01/2022               NaN      NaN               NaN               NaN
#
#            numberOfAnalystOpinions open openInterest operatingCashflow  \
# 31/01/2022                     NaN  NaN          NaN               NaN
#
#            operatingMargins payoutRatio pegRatio phone preMarketPrice  \
# 31/01/2022              NaN         NaN      NaN   NaN            NaN
#
#            previousClose priceHint priceToBook priceToSalesTrailing12Months  \
# 31/01/2022           NaN       NaN         NaN                          NaN
#
#            profitMargins quickRatio quoteType recommendationKey  \
# 31/01/2022           NaN        NaN       NaN               NaN
#
#            recommendationMean regularMarketDayHigh regularMarketDayLow  \
# 31/01/2022                NaN                  NaN                 NaN
#
#            regularMarketOpen regularMarketPreviousClose regularMarketPrice  \
# 31/01/2022               NaN                        NaN                NaN
#
#            regularMarketVolume returnOnAssets returnOnEquity revenueGrowth  \
# 31/01/2022                 NaN            NaN            NaN           NaN
#
#            revenuePerShare revenueQuarterlyGrowth sector sharesOutstanding  \
# 31/01/2022             NaN                    NaN    NaN               NaN
#
#            sharesPercentSharesOut sharesShort sharesShortPreviousMonthDate  \
# 31/01/2022                    NaN         NaN                          NaN
#
#            sharesShortPriorMonth shortName shortPercentOfFloat shortRatio  \
# 31/01/2022                   NaN       NaN                 NaN        NaN
#
#            startDate state strikePrice symbol targetHighPrice targetLowPrice  \
# 31/01/2022       NaN   NaN         NaN    NaN             NaN            NaN
#
#            targetMeanPrice targetMedianPrice threeYearAverageReturn  \
# 31/01/2022             NaN               NaN                    NaN
#
#            toCurrency totalAssets totalCash totalCashPerShare totalDebt  \
# 31/01/2022        NaN         NaN       NaN               NaN       NaN
#
#            totalRevenue tradeable trailingAnnualDividendRate  \
# 31/01/2022          NaN       NaN                        NaN
#
#            trailingAnnualDividendYield trailingEps trailingPE  \
# 31/01/2022                         NaN         NaN        NaN
#
#            trailingPegRatio twoHundredDayAverage volume volume24Hr  \
# 31/01/2022              NaN                  NaN    NaN        NaN
#
#            volumeAllCurrencies website yield ytdReturn  zip
# 31/01/2022                 NaN     NaN   NaN       NaN  NaN

# %%
info_df = pd.DataFrame([info], index=[date.today().strftime("%d/%m/%Y")])
info_df['companyOfficers'] = info_df['companyOfficers'].apply(lambda x:' '.join(x))
info_df
# Out:
#              zip      sector  fullTimeEmployees  \
# 31/01/2022  6300  Healthcare                410
#
#                                           longBusinessSummary city  \
# 31/01/2022  CRISPR Therapeutics AG, a gene editing company...  Zug
#
#                       phone      country companyOfficers  \
# 31/01/2022  41 41 561 32 77  Switzerland
#
#                              website  maxAge          address1       industry  \
# 31/01/2022  https://www.crisprtx.com       1  Baarerstrasse 14  Biotechnology
#
#             ebitdaMargins  profitMargins  grossMargins  operatingCashflow  \
# 31/01/2022        0.47175         0.4564       0.57168          543798016
#
#             revenueGrowth  operatingMargins     ebitda  targetLowPrice  \
# 31/01/2022          4.568           0.45595  425723008              90
#
#            recommendationKey  grossProfits  freeCashflow  targetMedianPrice  \
# 31/01/2022               buy    -266227000     281644640                160
#
#             currentPrice earningsGrowth  currentRatio  returnOnAssets  \
# 31/01/2022         63.18           None        26.183         0.11942
#
#             numberOfAnalystOpinions  targetMeanPrice  debtToEquity  \
# 31/01/2022                       18           151.56         8.173
#
#             returnOnEquity  targetHighPrice   totalCash  totalDebt  \
# 31/01/2022         0.21361              220  2477360128  205375008
#
#             totalRevenue  totalCashPerShare financialCurrency  \
# 31/01/2022     902433984             32.372               USD
#
#             revenuePerShare  quickRatio  recommendationMean exchange  \
# 31/01/2022           12.095      25.752                 2.1      NGM
#
#                          shortName                longName  \
# 31/01/2022  CRISPR Therapeutics AG  CRISPR Therapeutics AG
#
#            exchangeTimezoneName exchangeTimezoneShortName  isEsgPopulated  \
# 31/01/2022     America/New_York                       EST           False
#
#            gmtOffSetMilliseconds underlyingSymbol quoteType symbol  \
# 31/01/2022             -18000000             None    EQUITY   CRSP
#
#            underlyingExchangeSymbol headSymbol   messageBoardId  \
# 31/01/2022                     None       None  finmb_262549448
#
#                                             uuid     market  \
# 31/01/2022  10230d3e-917c-3849-a2ff-4a032541eb82  us_market
#
#            annualHoldingsTurnover  enterpriseToRevenue beta3Year  \
# 31/01/2022                   None                3.694      None
#
#             enterpriseToEbitda 52WeekChange morningStarRiskRating  forwardEps  \
# 31/01/2022                7.83         None                  None       -7.04
#
#            revenueQuarterlyGrowth  sharesOutstanding fundInceptionDate  \
# 31/01/2022                   None           76527000              None
#
#            annualReportExpenseRatio totalAssets  bookValue  sharesShort  \
# 31/01/2022                     None        None     32.864      8150373
#
#             sharesPercentSharesOut fundFamily  lastFiscalYearEnd  \
# 31/01/2022                  0.1065       None         1609372800
#
#             heldPercentInstitutions  netIncomeToCommon  trailingEps  \
# 31/01/2022                  0.54438          411870016        5.263
#
#            lastDividendValue SandP52WeekChange  priceToBook  \
# 31/01/2022              None              None     1.922468
#
#             heldPercentInsiders  nextFiscalYearEnd yield  mostRecentQuarter  \
# 31/01/2022              0.05591         1672444800  None         1632960000
#
#             shortRatio  sharesShortPreviousMonthDate  floatShares      beta  \
# 31/01/2022        5.06                    1636934400     72120541  2.076883
#
#             enterpriseValue  priceHint threeYearAverageReturn lastSplitDate  \
# 31/01/2022       3333615104          2                   None          None
#
#            lastSplitFactor legalType morningStarOverallRating  \
# 31/01/2022            None      None                     None
#
#            earningsQuarterlyGrowth  priceToSalesTrailing12Months  \
# 31/01/2022                    None                      5.357706
#
#             dateShortInterest  pegRatio ytdReturn  forwardPE lastCapGain  \
# 31/01/2022         1639526400     -0.07      None  -8.974432        None
#
#             shortPercentOfFloat  sharesShortPriorMonth category  \
# 31/01/2022               0.1545                5851185     None
#
#            fiveYearAverageReturn  previousClose  regularMarketOpen  \
# 31/01/2022                  None             59              60.29
#
#             twoHundredDayAverage trailingAnnualDividendYield  payoutRatio  \
# 31/01/2022              106.7594                        None            0
#
#            volume24Hr  regularMarketDayHigh navPrice  averageDailyVolume10Day  \
# 31/01/2022       None                 64.83     None                  2046300
#
#             regularMarketPreviousClose  fiftyDayAverage  \
# 31/01/2022                          59          73.7244
#
#            trailingAnnualDividendRate   open  averageVolume10days expireDate  \
# 31/01/2022                       None  60.29              2046300       None
#
#            algorithm dividendRate exDividendDate circulatingSupply startDate  \
# 31/01/2022      None         None           None              None      None
#
#             regularMarketDayLow currency  trailingPE  regularMarketVolume  \
# 31/01/2022                60.26      USD    12.00456              1271034
#
#            lastMarket maxSupply openInterest   marketCap volumeAllCurrencies  \
# 31/01/2022       None      None         None  4834975744                None
#
#            strikePrice  averageVolume  dayLow    ask  askSize   volume  \
# 31/01/2022        None        1644967   60.26  63.38      800  1271034
#
#             fiftyTwoWeekHigh fromCurrency fiveYearAvgDividendYield  \
# 31/01/2022            175.44         None                     None
#
#             fiftyTwoWeekLow    bid  tradeable dividendYield  bidSize  dayHigh  \
# 31/01/2022            55.35  63.32      False          None     1000    64.83
#
#             regularMarketPrice  preMarketPrice  \
# 31/01/2022               63.18           60.28
#
#                                           logo_url
# 31/01/2022  https://logo.clearbit.com/crisprtx.com

# %%
info_combo = empty.merge(info_df, how='right').set_index(empty.index)

# %%
info_combo[columns]
# Out:
#            52WeekChange SandP52WeekChange          address1 address2  \
# 31/01/2022         None              None  Baarerstrasse 14      NaN
#
#            algorithm annualHoldingsTurnover annualReportExpenseRatio    ask  \
# 31/01/2022      None                   None                     None  63.38
#
#             askSize  averageDailyVolume10Day  averageVolume  \
# 31/01/2022      800                  2046300        1644967
#
#             averageVolume10days      beta beta3Year    bid  bidSize  \
# 31/01/2022              2046300  2.076883      None  63.32     1000
#
#             bookValue category circulatingSupply city companyOfficers  \
# 31/01/2022     32.864     None              None  Zug
#
#                 country currency  currentPrice  currentRatio  \
# 31/01/2022  Switzerland      USD         63.18        26.183
#
#             dateShortInterest  dayHigh  dayLow  debtToEquity dividendRate  \
# 31/01/2022         1639526400    64.83   60.26         8.173         None
#
#            dividendYield earningsGrowth earningsQuarterlyGrowth     ebitda  \
# 31/01/2022          None           None                    None  425723008
#
#             ebitdaMargins  enterpriseToEbitda  enterpriseToRevenue  \
# 31/01/2022        0.47175                7.83                3.694
#
#             enterpriseValue exDividendDate exchange exchangeTimezoneName  \
# 31/01/2022       3333615104           None      NGM     America/New_York
#
#            exchangeTimezoneShortName expireDate  fax  fiftyDayAverage  \
# 31/01/2022                       EST       None  NaN          73.7244
#
#             fiftyTwoWeekHigh  fiftyTwoWeekLow financialCurrency  \
# 31/01/2022            175.44            55.35               USD
#
#            fiveYearAverageReturn fiveYearAvgDividendYield  floatShares  \
# 31/01/2022                  None                     None     72120541
#
#             forwardEps  forwardPE  freeCashflow fromCurrency  \
# 31/01/2022       -7.04  -8.974432     281644640         None
#
#             fullTimeEmployees fundFamily fundInceptionDate  \
# 31/01/2022                410       None              None
#
#            gmtOffSetMilliseconds  grossMargins  grossProfits  \
# 31/01/2022             -18000000       0.57168    -266227000
#
#             heldPercentInsiders  heldPercentInstitutions  \
# 31/01/2022              0.05591                  0.54438
#
#            impliedSharesOutstanding       industry  isEsgPopulated  \
# 31/01/2022                      NaN  Biotechnology           False
#
#            lastCapGain lastDividendDate lastDividendValue  lastFiscalYearEnd  \
# 31/01/2022        None              NaN              None         1609372800
#
#            lastMarket lastSplitDate lastSplitFactor legalType  \
# 31/01/2022       None          None            None      None
#
#                                           logo_url  \
# 31/01/2022  https://logo.clearbit.com/crisprtx.com
#
#                                           longBusinessSummary  \
# 31/01/2022  CRISPR Therapeutics AG, a gene editing company...
#
#                           longName     market   marketCap  maxAge maxSupply  \
# 31/01/2022  CRISPR Therapeutics AG  us_market  4834975744       1      None
#
#              messageBoardId morningStarOverallRating morningStarRiskRating  \
# 31/01/2022  finmb_262549448                     None                  None
#
#             mostRecentQuarter navPrice  netIncomeToCommon  nextFiscalYearEnd  \
# 31/01/2022         1632960000     None          411870016         1672444800
#
#             numberOfAnalystOpinions   open openInterest  operatingCashflow  \
# 31/01/2022                       18  60.29         None          543798016
#
#             operatingMargins  payoutRatio  pegRatio            phone  \
# 31/01/2022           0.45595            0     -0.07  41 41 561 32 77
#
#             preMarketPrice  previousClose  priceHint  priceToBook  \
# 31/01/2022           60.28             59          2     1.922468
#
#             priceToSalesTrailing12Months  profitMargins  quickRatio quoteType  \
# 31/01/2022                      5.357706         0.4564      25.752    EQUITY
#
#            recommendationKey  recommendationMean  regularMarketDayHigh  \
# 31/01/2022               buy                 2.1                 64.83
#
#             regularMarketDayLow  regularMarketOpen  \
# 31/01/2022                60.26              60.29
#
#             regularMarketPreviousClose  regularMarketPrice  \
# 31/01/2022                          59               63.18
#
#             regularMarketVolume  returnOnAssets  returnOnEquity  \
# 31/01/2022              1271034         0.11942         0.21361
#
#             revenueGrowth  revenuePerShare revenueQuarterlyGrowth      sector  \
# 31/01/2022          4.568           12.095                   None  Healthcare
#
#             sharesOutstanding  sharesPercentSharesOut  sharesShort  \
# 31/01/2022           76527000                  0.1065      8150373
#
#             sharesShortPreviousMonthDate  sharesShortPriorMonth  \
# 31/01/2022                    1636934400                5851185
#
#                          shortName  shortPercentOfFloat  shortRatio startDate  \
# 31/01/2022  CRISPR Therapeutics AG               0.1545        5.06      None
#
#            state strikePrice symbol  targetHighPrice  targetLowPrice  \
# 31/01/2022   NaN        None   CRSP              220              90
#
#             targetMeanPrice  targetMedianPrice threeYearAverageReturn  \
# 31/01/2022           151.56                160                   None
#
#            toCurrency totalAssets   totalCash  totalCashPerShare  totalDebt  \
# 31/01/2022        NaN        None  2477360128             32.372  205375008
#
#             totalRevenue  tradeable trailingAnnualDividendRate  \
# 31/01/2022     902433984      False                       None
#
#            trailingAnnualDividendYield  trailingEps  trailingPE  \
# 31/01/2022                        None        5.263    12.00456
#
#            trailingPegRatio  twoHundredDayAverage   volume volume24Hr  \
# 31/01/2022              NaN              106.7594  1271034       None
#
#            volumeAllCurrencies                   website yield ytdReturn   zip
# 31/01/2022                None  https://www.crisprtx.com  None      None  6300

# %%
round = ['targetLowPrice', 'targetMedianPrice', 'currentPrice', 'targetMeanPrice', 'targetHighPrice', 'previousClose', 'regularMarketOpen', 'twoHundredDayAverage', 'regularMarketDayHigh', 'regularMarketPreviousClose', 'fiftyDayAverage', 'open', 'regularMarketDayLow', 'dayLow', 'ask', 'fiftyTwoWeekHigh', 'fiftyTwoWeekLow', 'bid', 'dayHigh', 'regularMarketPrice', 'preMarketPrice']

# %%
a = (map(lambda x: x.lower(), round))
b = list(a)

# %%
sorted(b)
# Out:
# ['ask',
#  'bid',
#  'currentprice',
#  'dayhigh',
#  'daylow',
#  'fiftydayaverage',
#  'fiftytwoweekhigh',
#  'fiftytwoweeklow',
#  'open',
#  'premarketprice',
#  'previousclose',
#  'regularmarketdayhigh',
#  'regularmarketdaylow',
#  'regularmarketopen',
#  'regularmarketpreviousclose',
#  'regularmarketprice',
#  'targethighprice',
#  'targetlowprice',
#  'targetmeanprice',
#  'targetmedianprice',
#  'twohundreddayaverage']

# %%
info_df[round] = info_df[round].astype('int')

# %%
info_df
# Out:
#               zip      sector  fullTimeEmployees  \
# 31/01/2022  95014  Technology             100000
#
#                                           longBusinessSummary       city  \
# 31/01/2022  Apple Inc. designs, manufactures, and markets ...  Cupertino
#
#                    phone state        country companyOfficers  \
# 31/01/2022  408 996 1010    CA  United States
#
#                           website  maxAge            address1  \
# 31/01/2022  https://www.apple.com       1  One Apple Park Way
#
#                         industry  ebitdaMargins  profitMargins  grossMargins  \
# 31/01/2022  Consumer Electronics        0.33891        0.26579       0.43019
#
#             operatingCashflow  revenueGrowth  operatingMargins        ebitda  \
# 31/01/2022       112241000448          0.112             0.309  128217997312
#
#             targetLowPrice recommendationKey  grossProfits  freeCashflow  \
# 31/01/2022             128               buy  152836000000   80153247744
#
#             targetMedianPrice  currentPrice  earningsGrowth  currentRatio  \
# 31/01/2022                182           171            0.25         1.038
#
#             returnOnAssets  numberOfAnalystOpinions  targetMeanPrice  \
# 31/01/2022         0.19875                       42              180
#
#             debtToEquity  returnOnEquity  targetHighPrice    totalCash  \
# 31/01/2022       170.714         1.45567              210  63913000960
#
#                totalDebt  totalRevenue  totalCashPerShare financialCurrency  \
# 31/01/2022  122797998080  378323009536              3.916               USD
#
#             revenuePerShare  quickRatio  recommendationMean exchange  \
# 31/01/2022           22.838       0.875                 1.8      NMS
#
#              shortName    longName exchangeTimezoneName  \
# 31/01/2022  Apple Inc.  Apple Inc.     America/New_York
#
#            exchangeTimezoneShortName  isEsgPopulated gmtOffSetMilliseconds  \
# 31/01/2022                       EST           False             -18000000
#
#            quoteType symbol messageBoardId     market annualHoldingsTurnover  \
# 31/01/2022    EQUITY   AAPL    finmb_24937  us_market                   None
#
#             enterpriseToRevenue beta3Year  enterpriseToEbitda  52WeekChange  \
# 31/01/2022                7.503      None              22.139      0.269793
#
#            morningStarRiskRating  forwardEps revenueQuarterlyGrowth  \
# 31/01/2022                  None         6.2                   None
#
#             sharesOutstanding fundInceptionDate annualReportExpenseRatio  \
# 31/01/2022        16319399936              None                     None
#
#            totalAssets  bookValue  sharesShort  sharesPercentSharesOut  \
# 31/01/2022        None      4.402     90492581                  0.0055
#
#            fundFamily  lastFiscalYearEnd  heldPercentInstitutions  \
# 31/01/2022       None         1632528000                  0.59093
#
#             netIncomeToCommon  trailingEps  lastDividendValue  \
# 31/01/2022       100554997760        6.015               0.22
#
#             SandP52WeekChange  priceToBook  heldPercentInsiders  \
# 31/01/2022           0.174355    39.041344              0.00121
#
#             nextFiscalYearEnd yield  mostRecentQuarter  shortRatio  \
# 31/01/2022         1695600000  None         1640390400        0.94
#
#             sharesShortPreviousMonthDate  floatShares      beta  \
# 31/01/2022                    1639526400  16302958365  1.202736
#
#             enterpriseValue  priceHint threeYearAverageReturn  lastSplitDate  \
# 31/01/2022    2838575448064          2                   None     1598832000
#
#            lastSplitFactor legalType  lastDividendDate  \
# 31/01/2022             4:1      None        1636070400
#
#            morningStarOverallRating  earningsQuarterlyGrowth  \
# 31/01/2022                     None                    0.204
#
#             priceToSalesTrailing12Months  dateShortInterest  pegRatio  \
# 31/01/2022                       7.41338         1642118400      1.93
#
#            ytdReturn  forwardPE lastCapGain  shortPercentOfFloat  \
# 31/01/2022      None  27.719357        None               0.0055
#
#             sharesShortPriorMonth impliedSharesOutstanding category  \
# 31/01/2022              113277024                     None     None
#
#            fiveYearAverageReturn  previousClose  regularMarketOpen  \
# 31/01/2022                  None            170                165
#
#             twoHundredDayAverage  trailingAnnualDividendYield  payoutRatio  \
# 31/01/2022                   148                     0.005078       0.1515
#
#            volume24Hr  regularMarketDayHigh navPrice  averageDailyVolume10Day  \
# 31/01/2022       None                   172     None                116300610
#
#             regularMarketPreviousClose  fiftyDayAverage  \
# 31/01/2022                         170              169
#
#             trailingAnnualDividendRate  open toCurrency  averageVolume10days  \
# 31/01/2022                       0.865   165       None            116300610
#
#            expireDate algorithm  dividendRate  exDividendDate  \
# 31/01/2022       None      None          0.88      1643932800
#
#            circulatingSupply startDate  regularMarketDayLow currency  \
# 31/01/2022              None      None                  169      USD
#
#             trailingPE  regularMarketVolume lastMarket maxSupply openInterest  \
# 31/01/2022   28.571905             16731922       None      None         None
#
#                 marketCap volumeAllCurrencies strikePrice  averageVolume  \
# 31/01/2022  2804652179456                None        None       98747687
#
#             dayLow  ask  askSize    volume  fiftyTwoWeekHigh fromCurrency  \
# 31/01/2022     169  170      900  16731922               182         None
#
#             fiveYearAvgDividendYield  fiftyTwoWeekLow  bid  tradeable  \
# 31/01/2022                      1.17              116  170      False
#
#             dividendYield  bidSize  dayHigh  regularMarketPrice  \
# 31/01/2022         0.0052     1400      172                 171
#
#             preMarketPrice                             logo_url  \
# 31/01/2022             170  https://logo.clearbit.com/apple.com
#
#             trailingPegRatio
# 31/01/2022            3.3612

# %%
info_df['longBusinessSummary'] = info_df['longBusinessSummary'].apply(lambda x: x.replace(';', ' '))[0]

# %%
merged = empty.merge(info_df, how='right').set_index(empty.index).fillna('null')

# %%
from io import StringIO
buffer = StringIO()
merged.to_csv('notebooks', index_label='id', header=True, sep=";")

# %%
imp = pd.read_csv('notebooks', sep=";")

# %%
imp
# Out:
#            id  52WeekChange  SandP52WeekChange            address1  address2  \
# 0  31/01/2022      0.269793           0.174355  One Apple Park Way       NaN
#
#    algorithm  annualHoldingsTurnover  annualReportExpenseRatio     ask  \
# 0        NaN                     NaN                       NaN  170.46
#
#    askSize  averageDailyVolume10Day  averageVolume  averageVolume10days  \
# 0      900                116300610       98747687            116300610
#
#        beta  beta3Year     bid  bidSize  bookValue  category  \
# 0  1.202736        NaN  170.39     1400      4.402       NaN
#
#    circulatingSupply       city  companyOfficers        country currency  \
# 0                NaN  Cupertino              NaN  United States      USD
#
#    currentPrice  currentRatio  dateShortInterest  dayHigh  dayLow  \
# 0        171.86         1.038         1642118400  172.635  169.51
#
#    debtToEquity  dividendRate  dividendYield  earningsGrowth  \
# 0       170.714          0.88         0.0052            0.25
#
#    earningsQuarterlyGrowth        ebitda  ebitdaMargins  enterpriseToEbitda  \
# 0                    0.204  128217997312        0.33891              22.139
#
#    enterpriseToRevenue  enterpriseValue  exDividendDate exchange  \
# 0                7.503    2838575448064      1643932800      NMS
#
#   exchangeTimezoneName exchangeTimezoneShortName  expireDate  fax  \
# 0     America/New_York                       EST         NaN  NaN
#
#    fiftyDayAverage  fiftyTwoWeekHigh  fiftyTwoWeekLow financialCurrency  \
# 0         169.5848            182.94           116.21               USD
#
#    fiveYearAverageReturn  fiveYearAvgDividendYield  floatShares  forwardEps  \
# 0                    NaN                      1.17  16302958365         6.2
#
#    forwardPE  freeCashflow  fromCurrency  fullTimeEmployees  fundFamily  \
# 0  27.719357   80153247744           NaN             100000         NaN
#
#    fundInceptionDate  gmtOffSetMilliseconds  grossMargins  grossProfits  \
# 0                NaN              -18000000       0.43019  152836000000
#
#    heldPercentInsiders  heldPercentInstitutions  impliedSharesOutstanding  \
# 0              0.00121                  0.59093                       NaN
#
#                industry  isEsgPopulated  lastCapGain  lastDividendDate  \
# 0  Consumer Electronics           False          NaN        1636070400
#
#    lastDividendValue  lastFiscalYearEnd  lastMarket  lastSplitDate  \
# 0               0.22         1632528000         NaN     1598832000
#
#   lastSplitFactor  legalType                             logo_url  \
# 0             4:1        NaN  https://logo.clearbit.com/apple.com
#
#                                  longBusinessSummary    longName     market  \
# 0  Apple Inc. designs, manufactures, and markets ...  Apple Inc.  us_market
#
#        marketCap  maxAge  maxSupply messageBoardId  morningStarOverallRating  \
# 0  2804652179456       1        NaN    finmb_24937                       NaN
#
#    morningStarRiskRating  mostRecentQuarter  navPrice  netIncomeToCommon  \
# 0                    NaN         1640390400       NaN       100554997760
#
#    nextFiscalYearEnd  numberOfAnalystOpinions    open  openInterest  \
# 0         1695600000                       42  165.71           NaN
#
#    operatingCashflow  operatingMargins  payoutRatio  pegRatio         phone  \
# 0       112241000448             0.309       0.1515      1.93  408 996 1010
#
#    preMarketPrice  previousClose  priceHint  priceToBook  \
# 0          170.24         170.33          2    39.041344
#
#    priceToSalesTrailing12Months  profitMargins  quickRatio quoteType  \
# 0                       7.41338        0.26579       0.875    EQUITY
#
#   recommendationKey  recommendationMean  regularMarketDayHigh  \
# 0               buy                 1.8               172.635
#
#    regularMarketDayLow  regularMarketOpen  regularMarketPreviousClose  \
# 0               169.51             165.71                      170.33
#
#    regularMarketPrice  regularMarketVolume  returnOnAssets  returnOnEquity  \
# 0              171.86             16731922         0.19875         1.45567
#
#    revenueGrowth  revenuePerShare  revenueQuarterlyGrowth      sector  \
# 0          0.112           22.838                     NaN  Technology
#
#    sharesOutstanding  sharesPercentSharesOut  sharesShort  \
# 0        16319399936                  0.0055     90492581
#
#    sharesShortPreviousMonthDate  sharesShortPriorMonth   shortName  \
# 0                    1639526400              113277024  Apple Inc.
#
#    shortPercentOfFloat  shortRatio  startDate state  strikePrice symbol  \
# 0               0.0055        0.94        NaN    CA          NaN   AAPL
#
#    targetHighPrice  targetLowPrice  targetMeanPrice  targetMedianPrice  \
# 0              210          128.01           180.94                182
#
#    threeYearAverageReturn  toCurrency  totalAssets    totalCash  \
# 0                     NaN         NaN          NaN  63913000960
#
#    totalCashPerShare     totalDebt  totalRevenue  tradeable  \
# 0              3.916  122797998080  378323009536      False
#
#    trailingAnnualDividendRate  trailingAnnualDividendYield  trailingEps  \
# 0                       0.865                     0.005078        6.015
#
#    trailingPE  trailingPegRatio  twoHundredDayAverage    volume  volume24Hr  \
# 0   28.571905            3.3612              148.1168  16731922         NaN
#
#    volumeAllCurrencies                website  yield  ytdReturn    zip
# 0                  NaN  https://www.apple.com    NaN        NaN  95014

# %%
f = open(r'notebooks', 'r')

# %%
f
# Out:
# <_io.TextIOWrapper name='notebooks' mode='r' encoding='UTF-8'>

# %%
imp.dtypes
# Out:
# id                               object
# 52WeekChange                    float64
# SandP52WeekChange               float64
# address1                         object
# address2                        float64
# algorithm                       float64
# annualHoldingsTurnover          float64
# annualReportExpenseRatio        float64
# ask                             float64
# askSize                           int64
# averageDailyVolume10Day           int64
# averageVolume                     int64
# averageVolume10days               int64
# beta                            float64
# beta3Year                       float64
# bid                             float64
# bidSize                           int64
# bookValue                       float64
# category                        float64
# circulatingSupply               float64
# city                             object
# companyOfficers                 float64
# country                          object
# currency                         object
# currentPrice                    float64
# currentRatio                    float64
# dateShortInterest                 int64
# dayHigh                         float64
# dayLow                          float64
# debtToEquity                    float64
# dividendRate                    float64
# dividendYield                   float64
# earningsGrowth                  float64
# earningsQuarterlyGrowth         float64
# ebitda                            int64
# ebitdaMargins                   float64
# enterpriseToEbitda              float64
# enterpriseToRevenue             float64
# enterpriseValue                   int64
# exDividendDate                    int64
# exchange                         object
# exchangeTimezoneName             object
# exchangeTimezoneShortName        object
# expireDate                      float64
# fax                             float64
# fiftyDayAverage                 float64
# fiftyTwoWeekHigh                float64
# fiftyTwoWeekLow                 float64
# financialCurrency                object
# fiveYearAverageReturn           float64
# fiveYearAvgDividendYield        float64
# floatShares                       int64
# forwardEps                      float64
# forwardPE                       float64
# freeCashflow                      int64
# fromCurrency                    float64
# fullTimeEmployees                 int64
# fundFamily                      float64
# fundInceptionDate               float64
# gmtOffSetMilliseconds             int64
# grossMargins                    float64
# grossProfits                      int64
# heldPercentInsiders             float64
# heldPercentInstitutions         float64
# impliedSharesOutstanding        float64
# industry                         object
# isEsgPopulated                     bool
# lastCapGain                     float64
# lastDividendDate                  int64
# lastDividendValue               float64
# lastFiscalYearEnd                 int64
# lastMarket                      float64
# lastSplitDate                     int64
# lastSplitFactor                  object
# legalType                       float64
# logo_url                         object
# longBusinessSummary              object
# longName                         object
# market                           object
# marketCap                         int64
# maxAge                            int64
# maxSupply                       float64
# messageBoardId                   object
# morningStarOverallRating        float64
# morningStarRiskRating           float64
# mostRecentQuarter                 int64
# navPrice                        float64
# netIncomeToCommon                 int64
# nextFiscalYearEnd                 int64
# numberOfAnalystOpinions           int64
# open                            float64
# openInterest                    float64
# operatingCashflow                 int64
# operatingMargins                float64
# payoutRatio                     float64
# pegRatio                        float64
# phone                            object
# preMarketPrice                  float64
# previousClose                   float64
# priceHint                         int64
# priceToBook                     float64
# priceToSalesTrailing12Months    float64
# profitMargins                   float64
# quickRatio                      float64
# quoteType                        object
# recommendationKey                object
# recommendationMean              float64
# regularMarketDayHigh            float64
# regularMarketDayLow             float64
# regularMarketOpen               float64
# regularMarketPreviousClose      float64
# regularMarketPrice              float64
# regularMarketVolume               int64
# returnOnAssets                  float64
# returnOnEquity                  float64
# revenueGrowth                   float64
# revenuePerShare                 float64
# revenueQuarterlyGrowth          float64
# sector                           object
# sharesOutstanding                 int64
# sharesPercentSharesOut          float64
# sharesShort                       int64
# sharesShortPreviousMonthDate      int64
# sharesShortPriorMonth             int64
# shortName                        object
# shortPercentOfFloat             float64
# shortRatio                      float64
# startDate                       float64
# state                            object
# strikePrice                     float64
# symbol                           object
# targetHighPrice                   int64
# targetLowPrice                  float64
# targetMeanPrice                 float64
# targetMedianPrice                 int64
# threeYearAverageReturn          float64
# toCurrency                      float64
# totalAssets                     float64
# totalCash                         int64
# totalCashPerShare               float64
# totalDebt                         int64
# totalRevenue                      int64
# tradeable                          bool
# trailingAnnualDividendRate      float64
# trailingAnnualDividendYield     float64
# trailingEps                     float64
# trailingPE                      float64
# trailingPegRatio                float64
# twoHundredDayAverage            float64
# volume                            int64
# volume24Hr                      float64
# volumeAllCurrencies             float64
# website                          object
# yield                           float64
# ytdReturn                       float64
# zip                               int64
# dtype: object

# %%
buffer.seek(0)
# Out:
# 0

# %%
info_df
# Out:
#               zip       sector  fullTimeEmployees  \
# 30/01/2022  20817  Industrials             114000
#
#                                           longBusinessSummary      city  \
# 30/01/2022  Lockheed Martin Corporation, a security and ae...  Bethesda
#
#                    phone state        country companyOfficers  \
# 30/01/2022  301-897-6000    MD  United States
#
#                                    website  maxAge              address1  \
# 30/01/2022  https://www.lockheedmartin.com       1  6801 Rockledge Drive
#
#                        industry  ebitdaMargins  profitMargins  grossMargins  \
# 30/01/2022  Aerospace & Defense        0.13439        0.09419       0.13569
#
#             operatingCashflow  revenueGrowth  operatingMargins      ebitda  \
# 30/01/2022         9221000192          0.041           0.11665  9009999872
#
#             targetLowPrice recommendationKey  grossProfits  freeCashflow  \
# 30/01/2022             350               buy    9097000000    4866500096
#
#             targetMedianPrice  currentPrice  earningsGrowth  currentRatio  \
# 30/01/2022                404        393.15           0.171         1.416
#
#             returnOnAssets  numberOfAnalystOpinions  targetMeanPrice  \
# 30/01/2022         0.09624                       16           404.31
#
#             debtToEquity  returnOnEquity  targetHighPrice   totalCash  \
# 30/01/2022       119.317         0.74307              450  3604000000
#
#               totalDebt  totalRevenue  totalCashPerShare financialCurrency  \
# 30/01/2022  13075999744   67043999744             13.234               USD
#
#             revenuePerShare  quickRatio  recommendationMean exchange  \
# 30/01/2022          242.562       1.154                 2.4      NYQ
#
#                               shortName                     longName  \
# 30/01/2022  Lockheed Martin Corporation  Lockheed Martin Corporation
#
#            exchangeTimezoneName exchangeTimezoneShortName  isEsgPopulated  \
# 30/01/2022     America/New_York                       EST           False
#
#            gmtOffSetMilliseconds quoteType symbol messageBoardId     market  \
# 30/01/2022             -18000000    EQUITY    LMT   finmb_285827  us_market
#
#            annualHoldingsTurnover  enterpriseToRevenue beta3Year  \
# 30/01/2022                   None                1.738      None
#
#             enterpriseToEbitda  52WeekChange morningStarRiskRating  \
# 30/01/2022              12.934      0.213314                  None
#
#             forwardEps revenueQuarterlyGrowth  sharesOutstanding  \
# 30/01/2022       27.94                   None          272327008
#
#            fundInceptionDate annualReportExpenseRatio totalAssets  bookValue  \
# 30/01/2022              None                     None        None     40.439
#
#             sharesShort  sharesPercentSharesOut fundFamily  lastFiscalYearEnd  \
# 30/01/2022      2852041                  0.0105       None         1640908800
#
#             heldPercentInstitutions  netIncomeToCommon  trailingEps  \
# 30/01/2022                  0.75367         6314999808        22.76
#
#             lastDividendValue  SandP52WeekChange  priceToBook  \
# 30/01/2022                2.8           0.174355     9.722051
#
#             heldPercentInsiders  nextFiscalYearEnd yield  mostRecentQuarter  \
# 30/01/2022              0.00124         1703980800  None         1640908800
#
#             shortRatio  sharesShortPreviousMonthDate  floatShares      beta  \
# 30/01/2022        1.94                    1639526400    232273081  0.931069
#
#             enterpriseValue  priceHint threeYearAverageReturn  lastSplitDate  \
# 30/01/2022     116537327616          2                   None      915408000
#
#            lastSplitFactor legalType  lastDividendDate  \
# 30/01/2022             2:1      None        1638230400
#
#            morningStarOverallRating  earningsQuarterlyGrowth  \
# 30/01/2022                     None                    0.143
#
#             priceToSalesTrailing12Months  dateShortInterest  pegRatio  \
# 30/01/2022                      1.596942         1642118400      3.06
#
#            ytdReturn  forwardPE lastCapGain  shortPercentOfFloat  \
# 30/01/2022      None  14.071223        None               0.0124
#
#             sharesShortPriorMonth impliedSharesOutstanding category  \
# 30/01/2022                2569322                     None     None
#
#            fiveYearAverageReturn  previousClose  regularMarketOpen  \
# 30/01/2022                  None         389.08              389.1
#
#             twoHundredDayAverage  trailingAnnualDividendYield  payoutRatio  \
# 30/01/2022             363.68854                     0.027244       0.4657
#
#            volume24Hr  regularMarketDayHigh navPrice  averageDailyVolume10Day  \
# 30/01/2022       None                393.33     None                  2743350
#
#             regularMarketPreviousClose  fiftyDayAverage  \
# 30/01/2022                      389.08         353.8298
#
#             trailingAnnualDividendRate   open toCurrency  averageVolume10days  \
# 30/01/2022                        10.6  389.1       None              2743350
#
#            expireDate algorithm  dividendRate  exDividendDate  \
# 30/01/2022       None      None          11.2      1638230400
#
#            circulatingSupply startDate  regularMarketDayLow currency  \
# 30/01/2022              None      None               384.78      USD
#
#             trailingPE  regularMarketVolume lastMarket maxSupply openInterest  \
# 30/01/2022   17.273726              2145264       None      None         None
#
#                marketCap volumeAllCurrencies strikePrice  averageVolume  \
# 30/01/2022  107065360384                None        None        1736219
#
#             dayLow  ask  askSize   volume  fiftyTwoWeekHigh fromCurrency  \
# 30/01/2022  384.78  398     1000  2145264            396.99         None
#
#             fiveYearAvgDividendYield  fiftyTwoWeekLow  bid  tradeable  \
# 30/01/2022                      2.57           319.81  393      False
#
#             dividendYield  bidSize  dayHigh  regularMarketPrice  \
# 30/01/2022         0.0285      800   393.33              393.15
#
#            preMarketPrice                                      logo_url  \
# 30/01/2022           None  https://logo.clearbit.com/lockheedmartin.com
#
#             trailingPegRatio
# 30/01/2022           10.0214

# %%
merged.columns
# Out:
# Index(['trailingPegRatio', 'totalRevenue', 'financialCurrency', 'zip',
#        'impliedSharesOutstanding', 'regularMarketOpen', 'sharesShort',
#        'website', 'averageVolume', 'dividendYield',
#        ...
#        'address2', 'fax', 'sharesShortPriorMonth', 'logo_url', 'beta3Year',
#        'totalAssets', 'lastDividendValue', 'state', 'dayLow',
#        'enterpriseToEbitda'],
#       dtype='object', length=155)

# %%
trig = Yahoo('ADBE', 'y')

# %%
trig.get_preprocess()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <module>
# ----> 1 trig.get_preprocess()
#
# File ~/code/Michiel-DK/tracker/tracker/data_yahoo.py:335, in Yahoo.get_preprocess(self)
#     333 def get_preprocess(self):
#     334     """preprocess data"""
# --> 335     financials = self.get_financials()
#     336     ticker = self.ticker
#     337     financials = financials.reset_index().rename(columns={'index':'year'})
#
# TypeError: get_financials() missing 1 required positional argument: 'timing'

# %%
import pandas as pd
pd.set_option("display.max_rows", None, "display.max_columns", None)
preprocess = trig.preprocess()

# %%
columns = ['accountspayable',
 'assetturnover',
 'capitalexpenditures',
 'capitalsurplus',
 'cash',
 'cashdebt',
 'cashflow',
 'changeincash',
 'changetoaccountreceivables',
 'changetoinventory',
 'changetoliabilities',
 'changetonetincome',
 'changetooperatingactivities',
 'commonstock',
 'currentratio',
 'debtequity',
 'deferredlongtermassetcharges',
 'deferredlongtermliab',
 'depreciation',
 'dividendspaid',
 'earnings',
 'effectofexchangerate',
 'equityasset',
 'equitymultipl',
 'fcf',
 'fcfmargin',
 'financialleverage',
 'goodwill',
 'goodwillassets',
 'intangibleassets',
 'inventory',
 'investments',
 'issuanceofstock',
 'longtermdebt',
 'longterminvestments',
 'minorityinterest',
 'netborrowings',
 'netincome',
 'netmargin',
 'netreceivables',
 'nettangibleassets',
 'operatingmargin',
 'otherassets',
 'othercashflowsfromfinancingactivities',
 'othercashflowsfrominvestingactivities',
 'othercurrentassets',
 'othercurrentliab',
 'otherliab',
 'otherstockholderequity',
 'propertyplantequipment',
 'receivablessales',
 'repurchaseofstock',
 'retainedearnings',
 'revenue',
 'roa',
 'roe',
 'shortlongtermdebt',
 'shortterminvestments',
 'ticker',
 'totalassets',
 'totalcashflowsfrominvestingactivities',
 'totalcashfromfinancingactivities',
 'totalcashfromoperatingactivities',
 'totalcurrentassets',
 'totalcurrentliabilities',
 'totalliab',
 'totalstockholderequity',
 'treasurystock',
 'year']

# %%
df = trig.get_financials()
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 df = trig.get_financials()
#       2 df
#
# NameError: name 'trig' is not defined

# %%
## df loop
for i in df.index:
    if (df.loc[i]=='int64')[0] or (df.loc[i]=='int32')[0] or (df.loc[i]=='int8')[0]:
        print(f"{i} BIGINT,")
    elif (df.loc[i]=='O')[0]:
        print(f"{i} VARCHAR(n),")
    else:
        print(f"{i} REAL,")
# Out:
# receivablessales REAL,
# currentratio REAL,
# financialleverage REAL,
# debtequity REAL,
# percentage REAL,
# year REAL,
# ticker VARCHAR(n),

# %% [markdown]
# ## DB CONNECTION TEST

# %%
from tracker.postgres import connect, config
import psycopg2

# %%
params = config(filename='/Users/admin/code/Michiel-DK/tracker/database.ini', section='postgresql')

# %%
conn = psycopg2.connect(**params)
		
# create a cursor
cur = conn.cursor()

# %%
cur.execute('''SELECT * from weekly_info''')

# %%
colnames = [desc[0] for desc in cur.description]

# %%
result = cur.fetchall();

# %%
import pandas as pd
weekly_info = pd.DataFrame(result, columns=colnames)

# %%
weekly_info[weekly_info['shortname'] == 'Kulicke and Soffa Industries, I']
# Out:
# Empty DataFrame
# Columns: [index, date, weekchange52, sandp52weekchange, address1, address2, algorithm, annualholdingsturnover, annualreportexpenseratio, ask, asksize, averagedailyvolume10day, averagevolume, averagevolume10days, beta, beta3year, bid, bidsize, bookvalue, category, circulatingsupply, city, companyofficers, country, currency, currentprice, currentratio, dateshortinterest, dayhigh, daylow, debttoequity, dividendrate, dividendyield, earningsgrowth, earningsquarterlygrowth, ebitda, ebitdamargins, enterprisetoebitda, enterprisetorevenue, enterprisevalue, exdividenddate, exchange, exchangetimezonename, exchangetimezoneshortname, expiredate, fax, fiftydayaverage, fiftytwoweekhigh, fiftytwoweeklow, financialcurrency, fiveyearaveragereturn, fiveyearavgdividendyield, floatshares, forwardeps, forwardpe, freecashflow, fromcurrency, fulltimeemployees, fundfamily, fundinceptiondate, gmtoffsetmilliseconds, grossmargins, grossprofits, heldpercentinsiders, heldpercentinstitutions, impliedsharesoutstanding, industry, isesgpopulated, lastcapgain, lastdividenddate, lastdividendvalue, lastfiscalyearend, lastmarket, lastsplitdate, lastsplitfactor, legaltype, logo_url, longbusinesssummary, longname, market, marketcap, maxage, maxsupply, messageboardid, morningstaroverallrating, morningstarriskrating, mostrecentquarter, navprice, netincometocommon, nextfiscalyearend, numberofanalystopinions, open, openinterest, operatingcashflow, operatingmargins, payoutratio, pegratio, phone, premarketprice, previousclose, ...]
# Index: []
#
# [0 rows x 158 columns]

# %%
cur.close()

# %%
cur = conn.cursor()
cur.execute('''SELECT * from quarterly_financials''')
colnames = [desc[0] for desc in cur.description]
result = cur.fetchall();
q_financials = pd.DataFrame(result, columns=colnames)
q_financials
# Out:
#      index    year  accountspayable  assetturnover  capitalexpenditures  \
# 0        0  2021Q3       2448300000       0.337400            -34000000
# 1        1  2021Q2       2244000000       0.405300            -31000000
# 2        2  2021Q1       2229700000       0.341600            -16100000
# 3        3  2020Q4       2050500000       0.396200           -108300000
# 4        0  2021Q3      21356000000       0.096400           -217000000
# ..     ...     ...              ...            ...                  ...
# 215      3  2020Q3                0            inf            -21762000
# 216      0  2021Q3         29422000       0.071066             -1393000
# 217      1  2021Q2         35982000       0.141071              -217000
# 218      2  2021Q1         15858000       0.176528               -18000
# 219      3  2020Q3                0            inf             -4270000
#
#      capitalsurplus         cash  cashdebt    cashflow  changeincash  ...  \
# 0                 0   1949100000  2.190000  -187300000    -349600000  ...
# 1                 0   2298700000  2.596000   361800000     174800000  ...
# 2                 0   2123900000  2.410000  -102900000    -520200000  ...
# 3                 0   2644000000  2.113000   190000000      47900000  ...
# 4       18108000000  12182000000  0.150900  7935000000    3636000000  ...
# ..              ...          ...       ...         ...           ...  ...
# 215               0            0       NaN    23252000      -4987000  ...
# 216      1850711000   6352775000  1.878305   342047000    1981989000  ...
# 217      1516533000   4365982000  3.103204  3982899000    5052701000  ...
# 218       804523000   1983318000       inf  3411765000    3449906000  ...
# 219               0            0       NaN   208189000     226519000  ...
#
#       totalassets  totalcashflowsfrominvestingactivities  \
# 0      6769700000                              -60500000
# 1      6743600000                              -51800000
# 2      6554100000                              -39800000
# 3      6494800000                             -133600000
# 4    148858000000                             -615000000
# ..            ...                                    ...
# 215             0                              -26059000
# 216   18454271000                             -306667000
# 217   15790208000                             -299838000
# 218   10201112000                              -37910000
# 219             0                               29309000
#
#      totalcashfromfinancingactivities  totalcashfromoperatingactivities  \
# 0                          -111500000                        -187300000
# 1                          -125800000                         361800000
# 2                          -378100000                        -102900000
# 3                           -11900000                         190000000
# 4                         -3643000000                        7935000000
# ..                                ...                               ...
# 215                          -2180000                          23252000
# 216                        1958735000                         342047000
# 217                        1374856000                        3982899000
# 218                          59820000                        3411765000
# 219                           3206000                         208189000
#
#      totalcurrentassets  totalcurrentliabilities     totalliab  \
# 0            4978400000               3030900000    4591300000
# 1            4976600000               2924500000    4483600000
# 2            4807200000               2736900000    4321200000
# 3            4934800000               2939500000    4343700000
# 4           28957000000              28533000000  135281000000
# ..                  ...                      ...           ...
# 215                   0                        0             0
# 216         15869717000               9615159000   13093774000
# 217         14238055000               9677564000   11166783000
# 218          8672543000               7256148000    7344667000
# 219                   0                        0             0
#
#      totalstockholderequity  treasurystock           key
# 0                2178600000     1296700000  2021Q3ZAL.DE
# 1                2260200000     1369800000  2021Q2ZAL.DE
# 2                2233100000     1462700000  2021Q1ZAL.DE
# 3                2151300000     1421600000  2020Q4ZAL.DE
# 4               13550000000    -6176000000    2021Q3ABBV
# ..                      ...            ...           ...
# 215                       0              0    2020Q3DOCN
# 216              5360497000        -432000    2021Q3COIN
# 217              4623425000        2774000    2021Q2COIN
# 218              2304408000        2118000    2021Q1COIN
# 219                       0              0    2020Q3COIN
#
# [220 rows x 72 columns]

# %%
len(q_financials['ticker'].unique())
# Out:
# 55

# %%
cur.execute('''SELECT * from yearly_financials''')
colnames = [desc[0] for desc in cur.description]
result = cur.fetchall();
y_financials = pd.DataFrame(result, columns=colnames)
y_financials
# Out:
#     index  year  accountspayable  assetturnover  capitalexpenditures  \
# 0       0  2020       2050500000         1.2290           -177600000
# 1       1  2019       1708300000         1.4960           -233700000
# 2       2  2018       1298900000         1.6660           -226100000
# 3       3  2017       1120000000         1.5060           -189100000
# 4       0  2020       2276000000         0.3042           -798000000
# ..    ...   ...              ...            ...                  ...
# 91      3  2017          3884000         0.2830             -2633000
# 92      0  2020                0         0.1155                    0
# 93      1  2019                0         0.1102                    0
# 94      2  2018                0         0.1514                    0
# 95      3  2017                0         0.1226                    0
#
#     capitalsurplus        cash    cashdebt     cashflow  changeincash  ...  \
# 0                0  2644000000    2.113000    527400000    1667500000  ...
# 1                0   976500000  177.500000    327200000     -18500000  ...
# 2                0   995000000  118.440000    212800000     -69700000  ...
# 3                0  1065500000   95.100000    193700000      92900000  ...
# 4      17384000000  8449000000    0.098200  17588000000  -31475000000  ...
# ..             ...         ...         ...          ...           ...  ...
# 91       866330000    42817000    0.206400    -34441000      -7198000  ...
# 92      1025676000     2459000    0.002214    145066000       -869000  ...
# 93      1009270000     4828000    0.004410   -378041000       3568000  ...
# 94       991919000     3272000    0.005383    119193000       3910000  ...
# 95       906521000     3515000    0.004997     82388000        711000  ...
#
#      totalassets  totalcashflowsfrominvestingactivities  \
# 0     6494800000                             -217800000
# 1     4333100000                             -290300000
# 2     3233700000                             -207000000
# 3     2980300000                              -88300000
# 4   150565000000                           -37557000000
# ..           ...                                    ...
# 91     824391000                             -448379000
# 92    2338593000                                      0
# 93    2280931000                                      0
# 94    1730324000                                      0
# 95    1720238000                                      0
#
#     totalcashfromfinancingactivities  totalcashfromoperatingactivities  \
# 0                         1354100000                         527400000
# 1                          -57300000                         327200000
# 2                          -75900000                         212800000
# 3                          -10600000                         193700000
# 4                       -11501000000                       17588000000
# ..                               ...                               ...
# 91                         475431000                         -34441000
# 92                        -145934999                         145066000
# 93                         381609000                        -378041000
# 94                        -115283000                         119193000
# 95                         -81677000                          82388000
#
#     totalcurrentassets  totalcurrentliabilities     totalliab  \
# 0           4934800000               2939500000    4343700000
# 1           2878100000               2106700000    2649400000
# 2           2473500000               1613700000    1684700000
# 3           2410700000               1369400000    1441400000
# 4          24173000000              28661000000  137468000000
# ..                 ...                      ...           ...
# 91           156239000                 40330000     265488000
# 92            39723000                 47468000    1177278000
# 93            35003000                 43270000    1161634000
# 94            24355000                157151000     667122000
# 95            26515000                 37236000     750954000
#
#     totalstockholderequity  treasurystock         key
# 0               2151300000     1421600000  2020ZAL.DE
# 1               1683900000     1184800000  2019ZAL.DE
# 2               1549100000     1150500000  2018ZAL.DE
# 3               1539000000     1191100000  2017ZAL.DE
# 4              13076000000    -5381000000    2020ABBV
# ..                     ...            ...         ...
# 91               558903000        4089000    2017TDOC
# 92              1161315000       -4291000    2020TSLX
# 93              1119297000       -1359000    2019TSLX
# 94              1063202000       -1359000    2018TSLX
# 95               969284000       -1359000    2017TSLX
#
# [96 rows x 72 columns]

# %%
len(y_financials['ticker'].unique())
# Out:
# 24

# %%
cur = conn.cursor()
cur.execute('''SELECT * from quarterly_moat''')
colnames = [desc[0] for desc in cur.description]
result = cur.fetchall();
q_moat = pd.DataFrame(result, columns=colnames).drop(columns='index')
#yearly_moat['year'] = yearly_moat['year'].astype('int')

# %%
len(q_moat['ticker'].unique())
# Out:
# 55

# %%
cur.execute('''SELECT * from yearly_moat''')
colnames = [desc[0] for desc in cur.description]
result = cur.fetchall();
y_moat = pd.DataFrame(result, columns=colnames).drop(columns='index')

# %%
y_moat['ticker'].unique()
# Out:
# array(['ZAL.DE', 'ABBV', 'ADBE', 'AMGN', 'AY', 'BABA', 'CARM.PA', 'CRM',
#        'CRSP', 'CVS', 'DUKE.L', 'EURN', 'GAIN', 'GOOGL', 'HASI', 'NXR.L',
#        'MO', 'MSFT', 'PYPL', 'RDS-A', 'SQ', 'TCPC', 'TDOC', 'TSLX'],
#       dtype=object)

# %%
yearly_moat[yearly_moat['year']==2021]['ticker']
# Out:
# 4        ADBE
# 16       BABA
# 24        CRM
# 36     DUKE.L
# 44       GAIN
# 56      NXR.L
# 64       MSFT
# 100    TRI.PA
# 128       WSM
# 140      AAPL
# 148      AVGO
# 164       MDB
# 176      KLIC
# 180      QCOM
# 184      CRWD
# 201      ASML
# 205       TXN
# 209       SMG
# Name: ticker, dtype: object

# %%
tickers = set(yearly_moat['ticker'])

# %%
import numpy as np
np.mean(yearly_moat[yearly_moat['ticker']=="ABBV"]['moatpercentage'])
# Out:
# 6.304749999999999

# %%
for i in yearly_moat[yearly_moat['year']==2021]['ticker']:
    print(f"{i} {np.mean([np.round(np.mean(yearly_moat[yearly_moat['ticker']==i]['moatpercentage']),2),np.round(np.mean(yearly_health[yearly_health['ticker']==i]['percentage']),2)])}")
# Out:
# ADBE 6.585
# BABA 5.785
# CRM 4.3
# DUKE.L 11.215
# GAIN 11.25
# NXR.L 1.98
# MSFT 5.3950000000000005
# TRI.PA 3.09
# WSM 3.7800000000000002
# AAPL 4.11
# AVGO 5.475
# MDB -4.865
# KLIC 3.085
# QCOM 2.615
# CRWD -6.655
# ASML 5.325
# TXN 7.21
# SMG 2.01

# %%
for i in yearly_health[yearly_health['year']==2021]['ticker']:
    print(f"{i} avg moat {np.mean(yearly_health[yearly_health['ticker']==i]['percentage'])}")
# Out:
# ADBE avg moat 3.16
# BABA avg moat 3.6332500000000003
# CRM avg moat 5.493
# DUKE.L avg moat 9.7585
# GAIN avg moat 2.2815
# NXR.L avg moat 2.46225
# MSFT avg moat 1.97375
# TRI.PA avg moat 3.9285000000000005
# WSM avg moat 5.3774999999999995
# AAPL avg moat 1.2697500000000002
# AVGO avg moat 1.9135
# MDB avg moat 1.864
# KLIC avg moat 2.8994999999999997
# QCOM avg moat 1.2559
# CRWD avg moat 0.1704250000000001
# ASML avg moat 2.59425
# TXN avg moat 2.9762500000000003
# SMG avg moat 1.3130000000000002

# %%
import matplotlib.pyplot as plt

# %%
pd.pivot_table(yearly_moat, index='ticker', columns='year', values='moatpercentage')
# Out:
# year        2017       2018     2019        2020    2021
# ticker
# AAPL         NaN     6.8830   6.5000      6.6200   7.780
# ABBV      6.4500     6.3900   7.9140      4.4650     NaN
# ABT       1.3480     2.8260   3.6700      4.1680     NaN
# ADBE         NaN     9.3360   8.4840     12.3300   9.890
# AKAM      3.5160     4.3700   5.5270      5.6330     NaN
# AMGN      4.6300    11.1300  10.2660      9.1500     NaN
# AMZN      0.7026     1.5400   1.5110      1.8600     NaN
# APO       7.3800     3.8960   9.3200     -2.2520     NaN
# ASML         NaN     7.1300   6.6300      7.7580  10.710
# AVGO         NaN    16.6600   5.1840      5.6700   8.664
# AY       -0.6810     2.9360   3.3180      2.4980     NaN
# BABA         NaN     8.6900   7.5160      8.8700   6.670
# CARM.PA  28.8800    12.5700   9.1950     -9.1900     NaN
# COIN         NaN        NaN  -2.9360     18.7700     NaN
# CRM          NaN     2.0250   3.2460      1.3830   5.797
# CRSP    -51.0000 -1471.0000   6.6450 -13840.0000     NaN
# CRWD         NaN   -31.5500 -14.8900     -6.8200  -0.680
# CVS       1.0730     0.1262   0.8690      0.9404     NaN
# DOCN         NaN    -4.1300  -3.9120     -3.6370     NaN
# DUKE.L       NaN   -12.7700  11.1700     34.1000  18.190
# EURN      0.8755    -6.1050   4.4920     12.9500     NaN
# FB       12.1800    11.5700   8.3360     10.0600     NaN
# FISV      6.6000     6.2420   3.4120      2.8380     NaN
# GAIN         NaN    22.9400  42.1000      0.1600  15.690
# GOOGL     4.1250     6.6760   6.4500      6.8550     NaN
# HASI     20.3300    21.4200  28.0500     28.6400     NaN
# IIPR      3.8900    17.3100  18.3300     18.9400     NaN
# KLIC         NaN     2.2200   1.0970      2.8030   6.960
# KMI       1.1880     3.8750   5.2930      1.7350     NaN
# MCO       6.7460     8.9450   9.0550     10.2200     NaN
# MDB          NaN   -13.9700 -10.0860    -10.6700 -11.620
# MELI      1.2130    -0.0422  -1.0380      1.3340     NaN
# MO       14.2340    10.9840   0.4512      7.3900     NaN
# MSFT         NaN     5.4020   9.4600      9.4700  10.940
# NXR.L        NaN     1.0220   1.8440      1.1350   1.983
# OKE       1.1930     2.5020   2.6070      1.9270     NaN
# PYPL      4.2070     4.9650   4.4770      6.1250     NaN
# QCOM         NaN    -4.6300   5.9100      6.5270   8.090
# RDS-A     1.3980     1.9750   1.5190     -2.3220     NaN
# SHOP     -1.5210    -1.5420  -1.8560      3.4060     NaN
# SMG          NaN     1.1730   3.9320      2.9730   2.773
# SOFI    -28.5600    -3.0550 -14.3600    -14.4700     NaN
# SQ       -0.4392     0.1154   2.4400      0.7095     NaN
# TCPC      5.6370     4.5900   3.9940     14.0200     NaN
# TDOC    -12.1250    -5.8320  -4.1450    -11.2100     NaN
# TMO       3.5490     3.8460   4.4600      6.0700     NaN
# TRI.PA       NaN     2.2910   2.0080      2.1880   2.523
# TROW      7.7100     9.9200  10.6600     10.9400     NaN
# TSLX     15.1400    13.6300   7.1500     19.1400     NaN
# TTE       1.8570     1.8780   2.0550     -1.1920     NaN
# TWLO     -4.0800    -4.5940  -6.7730     -6.8320     NaN
# TXN          NaN    10.8600  10.8360     11.6300  12.450
# WSM          NaN     1.5700   1.8680      1.9120   3.377

# %%
cur = conn.cursor()
cur.execute('''SELECT * from yearly_health''')
colnames = [desc[0] for desc in cur.description]
result = cur.fetchall();
yearly_health = pd.DataFrame(result, columns=colnames)
yearly_health['year'] = yearly_health['year'].astype('int')
pd.pivot_table(yearly_health, index='ticker', columns='year', values='percentage')
# Out:
# year        2017     2018     2019     2020   2021
# ticker
# AAPL         NaN   1.3440   1.3770   1.2490  1.109
# ABBV      0.6980   0.3930   1.0370   0.6855    NaN
# ABT       1.7220   1.8200   1.8860   1.8820    NaN
# ADBE         NaN   2.0590   5.1520   2.7000  2.729
# AKAM      3.7000   2.8300   2.4000   2.3220    NaN
# AMGN      2.4040   1.3970   0.9697   1.0090    NaN
# AMZN      1.8300   2.1330   2.3960   2.6460    NaN
# APO       1.2830   0.9033   1.2550   1.0310    NaN
# ASML         NaN   3.0000   2.9860   2.4900  1.901
# AVGO         NaN   2.4690   1.4740   1.6540  2.057
# AY        1.1160   0.9453   0.7646   1.1880    NaN
# BABA         NaN   2.7480   3.2850   4.1400  4.360
# CARM.PA   1.7530   1.5120   1.5140   1.4100    NaN
# COIN         NaN      NaN   1.2940   1.1830    NaN
# CRM          NaN   6.4800   2.7500   5.8120  6.930
# CRSP      7.9300   6.7460   7.5940   7.2930    NaN
# CRWD         NaN  -1.7880  -0.8833   1.7390  1.614
# CVS       2.1840   1.5490   1.7120   1.7450    NaN
# DOCN         NaN      NaN  -0.2489   0.2095    NaN
# DUKE.L       NaN  13.1000   5.2540  15.1300  5.550
# EURN      2.2480   1.6840   1.9770   2.3400    NaN
# FB        6.0600   4.1640   3.0960   3.3890    NaN
# FISV      1.0870   0.9717   1.5010   1.6720    NaN
# GAIN         NaN   2.0620   2.4470   2.5470  2.070
# GOOGL    16.9400  19.0200  21.0200   8.3300    NaN
# HASI     11.9700   7.8900   8.5000   8.3400    NaN
# IIPR      4.0900   2.9180   5.0100   3.5120    NaN
# KLIC         NaN   3.1860   2.8850   3.0350  2.492
# KMI       1.4260   1.5780   1.6130   1.5390    NaN
# MCO       0.4795   0.7000   0.7944   0.9600    NaN
# MDB          NaN   2.0640   1.9340   2.0250  1.433
# MELI      1.0310   0.8520   2.3600   1.5350    NaN
# MO        2.9790   4.7540   8.5000   9.8050    NaN
# MSFT         NaN   1.7340   1.8310   2.0450  2.285
# NXR.L        NaN   1.7090   2.0600   1.7400  4.340
# OKE       1.3820   1.7610   1.4130   1.4090    NaN
# PYPL      1.6830   1.3510   1.2470   1.3490    NaN
# QCOM         NaN   0.9126   1.3690   1.2220  1.520
# RDS-A     2.4730   2.8540   2.5570   1.9640    NaN
# SHOP      7.3630   7.9140   5.1370   7.4450    NaN
# SMG          NaN   1.0840   1.4760   1.2290  1.463
# SOFI         NaN  34.3400  25.9000   3.1390    NaN
# SQ        1.8520   1.8030   1.9640   1.6190    NaN
# TCPC      2.3890   2.0370   1.8480   1.6380    NaN
# TDOC      3.1950   4.3120   3.7320   6.3830    NaN
# TMO       1.6210   1.8340   1.9620   2.0200    NaN
# TRI.PA       NaN   2.8000   3.5880   4.4960  4.830
# TROW      2.9590   2.6910   2.5940   2.3800    NaN
# TSLX      3.2070   3.3120   2.2810   3.0640    NaN
# TTE       2.2030   2.2700   2.1070   1.7295    NaN
# TWLO      3.3380   3.2340   4.5000   4.2800    NaN
# TXN          NaN   2.9410   2.9920   2.7360  3.236
# WSM          NaN   6.0100   5.4840   5.1680  4.848

# %%
yearly_health
# Out:
#      index  receivablessales  currentratio  financialleverage  debtequity  \
# 0        0            1.2980        0.8433             0.3474     0.25300
# 1        1            1.5320        3.1780            -0.3667    -0.19460
# 2        2            1.5205        0.9830            -0.5693    -0.36180
# 3        3            0.9820        1.2750             0.2880     0.24700
# 4        0            2.1020        1.2510             2.1740     5.38300
# ..     ...               ...           ...                ...         ...
# 179      3            0.9136        5.6700             2.9700         NaN
# 180      0            2.3440        1.6800             0.9653     1.09000
# 181      1            1.4690        2.1350             0.6830     0.59860
# 182      2            2.4550        1.8760             0.5957     0.54830
# 183      3            1.9460        1.5260             0.0987     0.07874
#
#      percentage  year ticker
# 0        0.6855  2020   ABBV
# 1        1.0370  2019   ABBV
# 2        0.3930  2018   ABBV
# 3        0.6980  2017   ABBV
# 4        2.7290  2021   ADBE
# ..          ...   ...    ...
# 179      3.1860  2018   KLIC
# 180      1.5200  2021   QCOM
# 181      1.2220  2020   QCOM
# 182      1.3690  2019   QCOM
# 183      0.9126  2018   QCOM
#
# [184 rows x 8 columns]
