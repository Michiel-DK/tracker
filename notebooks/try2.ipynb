# %%
from tracker.data_yahoo import Yahoo
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
adbe = Yahoo('HSI')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 adbe = Yahoo('HSI')
#
# File ~/code/Michiel-DK/tracker/tracker/data_yahoo.py:11, in Yahoo.__new__(cls, ticker)
#       9 if len(yf.Ticker(ticker).cashflow) < 1:
#      10     pass
# ---> 11 return super(Yahoo, cls).__new__(cls)
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
adbe.ticker
# Out:
# 'HHFA.DE'

# %%
adbe.get_financials()
# Out:
#       accountspayable  assetturnover  capitalexpenditures  capitalsurplus  \
# 2020         90913000              0           -174657000               0
# 2019         74879000              0           -169208000               0
# 2018         87043000              0           -126516000               0
# 2017         77246000              0           -126490000               0
#
#            cash  cashdebt  cashflow  changeincash  changetoaccountreceivables  \
# 2020   86858000         0         0     -39175000                           0
# 2019  113041000         0         0     -45967000                           0
# 2018  159010000         0         0      -1525000                           0
# 2017  181514000         0         0      23117000                           0
#
#       changetoinventory  changetoliabilities  changetonetincome  \
# 2020           -1962000              1108000           40872000
# 2019           12385000              1466000           43751000
# ...

# %%
adbe.get_preprocess()
# Out:
#    year  accountspayable  assetturnover  capitalexpenditures  capitalsurplus  \
# 0  2021        312000000              0           -348000000      8428000000
# 1  2020        306000000              0           -419000000      7357000000
# 2  2019        209000000              0           -395000000      6504000000
# 3  2018        186258000              0           -267000000      5685337000
#
#          cash  cashdebt    cashflow  changeincash  changetoaccountreceivables  \
# 0  3844000000         0  7230000000    -634000000                  -430000000
# 1  4478000000         0  5727000000    1828000000                   106000000
# 2  2650000000         0  4422000000    1007000000                  -188000000
# 3  1642775000         0  4029000000    -663000000                    -2000000
#
#    changetoinventory  changetoliabilities  changetonetincome  \
# 0                  0           1033000000         1328000000
# 1                  0            354000000         -476000000
# ...

# %%
fund = adbe.get_fundamentals()

# %%
fund
# Out:
#    year  accountspayable  assetturnover  capitalexpenditures  capitalsurplus  \
# 0  2021        312000000       0.579590           -348000000      8428000000
# 1  2020        306000000       0.529785           -419000000      7357000000
# 2  2019        209000000       0.538086           -395000000      6504000000
# 3  2018        186258000       0.481201           -267000000      5685337000
#
#          cash  cashdebt    cashflow  changeincash  changetoaccountreceivables  \
# 0  3844000000  0.932129  7230000000    -634000000                  -430000000
# 1  4478000000  1.087891  5727000000    1828000000                   106000000
# 2  2650000000  0.640625  4422000000    1007000000                  -188000000
# 3  1642775000  0.397217  4029000000    -663000000                    -2000000
#
#    changetoinventory  changetoliabilities  changetonetincome  \
# 0                  0           1033000000         1328000000
# 1                  0            354000000         -476000000
# ...

# %%
adbe.get_checklist()
# Out:
# (   operatingmargin  fcfmargin  netmargin       roa        roe  moatpercentage  \
#  0         3.052734   8.718750   2.035156  5.089844  30.546875        9.890625
#  1         2.966797   8.250000   2.724609  6.812500  40.875000       12.328125
#  2         2.638672   7.210938   1.760742  4.402344  26.421875        8.484375
#  3         2.974609   8.328125   1.912109  4.781250  28.687500        9.335938
#
#     year ticker
#  0  2021   ADBE
#  1  2020   ADBE
#  2  2019   ADBE
#  3  2018   ADBE  ,
#     receivablessales  currentratio  financialleverage  debtequity  percentage  \
#  0          2.101562      1.250977           2.173828    5.382812    2.728516
#  1          2.300781      1.477539           2.183594    4.835938    2.699219
#  2          1.818359      0.792969           2.029297   15.968750    5.152344
#  3          1.716797      1.128906           1.996094    3.396484    2.058594
#
#     year ticker
#  0  2021   ADBE
#  1  2020   ADBE
#  2  2019   ADBE
# ...
